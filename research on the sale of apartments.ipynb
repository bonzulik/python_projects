# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Работа-с-пропусками-и-изменением-типов-данных" data-toc-modified-id="Работа-с-пропусками-и-изменением-типов-данных-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Работа с пропусками и изменением типов данных</a></span><ul class="toc-item"><li><span><a href="#total_images-(23699-non-null-int64)" data-toc-modified-id="total_images-(23699-non-null-int64)-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>total_images (23699 non-null int64)</a></span></li><li><span><a href="#last_price-(23699-non-null-float64---заменить)" data-toc-modified-id="last_price-(23699-non-null-float64---заменить)-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>last_price (23699 non-null <em>float64 - заменить</em>)</a></span></li><li><span><a href="#total_area-(23699-non-null-float64)" data-toc-modified-id="total_area-(23699-non-null-float64)-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>total_area (23699 non-null float64)</a></span></li><li><span><a href="#first_day_exposition-(23699-non-null-object---заменить)" data-toc-modified-id="first_day_exposition-(23699-non-null-object---заменить)-2.1.4"><span class="toc-item-num">2.1.4&nbsp;&nbsp;</span>first_day_exposition (23699 non-null object - заменить)</a></span></li><li><span><a href="#rooms-(23699-non-null-int64)" data-toc-modified-id="rooms-(23699-non-null-int64)-2.1.5"><span class="toc-item-num">2.1.5&nbsp;&nbsp;</span>rooms (23699 non-null int64)</a></span></li><li><span><a href="#ceiling_height-(14504---38,8-%-пропусков-non-null-float64---заменить" data-toc-modified-id="ceiling_height-(14504---38,8-%-пропусков-non-null-float64---заменить-2.1.6"><span class="toc-item-num">2.1.6&nbsp;&nbsp;</span>ceiling_height (14504 - 38,8 % пропусков non-null float64 - заменить</a></span></li><li><span><a href="#floors_total-(23613---86-пропущенных-значений-non-null-float64---заменить)" data-toc-modified-id="floors_total-(23613---86-пропущенных-значений-non-null-float64---заменить)-2.1.7"><span class="toc-item-num">2.1.7&nbsp;&nbsp;</span>floors_total (23613 - 86 пропущенных значений non-null float64 - заменить)</a></span></li><li><span><a href="#living_area-(21796---8%-пропусков-non-null-float64)---требует-работы-с-пропусками" data-toc-modified-id="living_area-(21796---8%-пропусков-non-null-float64)---требует-работы-с-пропусками-2.1.8"><span class="toc-item-num">2.1.8&nbsp;&nbsp;</span>living_area (21796 - 8% пропусков non-null float64) - требует работы с пропусками</a></span></li><li><span><a href="#floor-(23699-non-null-int64)---корректен" data-toc-modified-id="floor-(23699-non-null-int64)---корректен-2.1.9"><span class="toc-item-num">2.1.9&nbsp;&nbsp;</span>floor (23699 non-null int64) - корректен</a></span></li><li><span><a href="#is_apartment-(2775---88.3%-пропусков-non-null-object)---требует-работы-с-пропусками" data-toc-modified-id="is_apartment-(2775---88.3%-пропусков-non-null-object)---требует-работы-с-пропусками-2.1.10"><span class="toc-item-num">2.1.10&nbsp;&nbsp;</span>is_apartment (2775 - 88.3% пропусков non-null object) - требует работы с пропусками</a></span></li><li><span><a href="#studio-(23699-non-null-bool)---корректен" data-toc-modified-id="studio-(23699-non-null-bool)---корректен-2.1.11"><span class="toc-item-num">2.1.11&nbsp;&nbsp;</span>studio (23699 non-null bool) - корректен</a></span></li><li><span><a href="#open_plan-(23699-non-null-bool)---корректен" data-toc-modified-id="open_plan-(23699-non-null-bool)---корректен-2.1.12"><span class="toc-item-num">2.1.12&nbsp;&nbsp;</span>open_plan (23699 non-null bool) - корректен</a></span></li><li><span><a href="#kitchen_area-(21421---9,6%-пропусков-non-null-float64)---требует-работы-с-пропусками" data-toc-modified-id="kitchen_area-(21421---9,6%-пропусков-non-null-float64)---требует-работы-с-пропусками-2.1.13"><span class="toc-item-num">2.1.13&nbsp;&nbsp;</span>kitchen_area (21421 - 9,6% пропусков non-null float64) - требует работы с пропусками</a></span></li><li><span><a href="#balcony-(12180---48,6%-пропусков-non-null-float64)---требует-работы-с-пропусками" data-toc-modified-id="balcony-(12180---48,6%-пропусков-non-null-float64)---требует-работы-с-пропусками-2.1.14"><span class="toc-item-num">2.1.14&nbsp;&nbsp;</span>balcony (12180 - 48,6% пропусков non-null float64) - требует работы с пропусками</a></span></li><li><span><a href="#locality_name-(23650---49-пропусков-non-null-object)---требует-работы-с-пропусками-и-доп.анализа" data-toc-modified-id="locality_name-(23650---49-пропусков-non-null-object)---требует-работы-с-пропусками-и-доп.анализа-2.1.15"><span class="toc-item-num">2.1.15&nbsp;&nbsp;</span>locality_name (23650 - 49 пропусков non-null object) - требует работы с пропусками и доп.анализа</a></span></li><li><span><a href="#airports_nearest-(18157---23,4%-пропусков-non-null-float64---заменить)---требует-работы-с-пропусками" data-toc-modified-id="airports_nearest-(18157---23,4%-пропусков-non-null-float64---заменить)---требует-работы-с-пропусками-2.1.16"><span class="toc-item-num">2.1.16&nbsp;&nbsp;</span>airports_nearest (18157 - 23,4% пропусков non-null float64 - заменить) - требует работы с пропусками</a></span></li><li><span><a href="#cityCenters_nearest-(18180---23,3%-пропусков-non-null-float64---заменить)---требует-приведения-названия-столбца-к-&quot;змеиному-регистру&quot;,-а-также-работы-с-пропусками" data-toc-modified-id="cityCenters_nearest-(18180---23,3%-пропусков-non-null-float64---заменить)---требует-приведения-названия-столбца-к-&quot;змеиному-регистру&quot;,-а-также-работы-с-пропусками-2.1.17"><span class="toc-item-num">2.1.17&nbsp;&nbsp;</span>cityCenters_nearest (18180 - 23,3% пропусков non-null float64 - заменить) - требует приведения названия столбца к "змеиному регистру", а также работы с пропусками</a></span></li><li><span><a href="#parks_around3000-(18181---23,3%-пропусков-non-null-float64---заменить)---требует-работы-с-пропусками" data-toc-modified-id="parks_around3000-(18181---23,3%-пропусков-non-null-float64---заменить)---требует-работы-с-пропусками-2.1.18"><span class="toc-item-num">2.1.18&nbsp;&nbsp;</span>parks_around3000 (18181 - 23,3% пропусков non-null float64 - заменить) - требует работы с пропусками</a></span></li><li><span><a href="#parks_nearest-(8079---65,9%-пропусков-non-null-float64---заменить)---требует-работы-с-пропусками" data-toc-modified-id="parks_nearest-(8079---65,9%-пропусков-non-null-float64---заменить)---требует-работы-с-пропусками-2.1.19"><span class="toc-item-num">2.1.19&nbsp;&nbsp;</span>parks_nearest (8079 - 65,9% пропусков non-null float64 - заменить) - требует работы с пропусками</a></span></li><li><span><a href="#ponds_around3000-(18181---23,3%-пропусков-non-null-float64---заменить)---требует-работы-с-пропусками" data-toc-modified-id="ponds_around3000-(18181---23,3%-пропусков-non-null-float64---заменить)---требует-работы-с-пропусками-2.1.20"><span class="toc-item-num">2.1.20&nbsp;&nbsp;</span>ponds_around3000 (18181 - 23,3% пропусков non-null float64 - заменить) - требует работы с пропусками</a></span></li><li><span><a href="#ponds_nearest-(9110---65,5%-пропусков-non-null-float64---заменить)---требует-работы-с-пропусками" data-toc-modified-id="ponds_nearest-(9110---65,5%-пропусков-non-null-float64---заменить)---требует-работы-с-пропусками-2.1.21"><span class="toc-item-num">2.1.21&nbsp;&nbsp;</span>ponds_nearest (9110 - 65,5% пропусков non-null float64 - заменить) - требует работы с пропусками</a></span></li><li><span><a href="#days_exposition-(20518---13,4%-пропусков-non-null-float64---заменить)---требует-работы-с-пропусками" data-toc-modified-id="days_exposition-(20518---13,4%-пропусков-non-null-float64---заменить)---требует-работы-с-пропусками-2.1.22"><span class="toc-item-num">2.1.22&nbsp;&nbsp;</span>days_exposition (20518 - 13,4% пропусков non-null float64 - заменить) - требует работы с пропусками</a></span></li></ul></li><li><span><a href="#Обработка-дубликатов" data-toc-modified-id="Обработка-дубликатов-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Обработка дубликатов</a></span></li><li><span><a href="#Предобработка-данных.-Выводы" data-toc-modified-id="Предобработка-данных.-Выводы-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Предобработка данных. Выводы</a></span></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span><ul class="toc-item"><li><span><a href="#Цена-квадратного-метра" data-toc-modified-id="Цена-квадратного-метра-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Цена квадратного метра</a></span></li><li><span><a href="#День-недели,-месяц-и-год-публикации-объявления" data-toc-modified-id="День-недели,-месяц-и-год-публикации-объявления-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>День недели, месяц и год публикации объявления</a></span></li><li><span><a href="#Этаж-квартиры;-варианты-—-первый,-последний,-другой;" data-toc-modified-id="Этаж-квартиры;-варианты-—-первый,-последний,-другой;-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Этаж квартиры; варианты — первый, последний, другой;</a></span></li><li><span><a href="#Cоотношение-жилой-и-общей-площади,-а-также-отношение-площади-кухни-к-общей." data-toc-modified-id="Cоотношение-жилой-и-общей-площади,-а-также-отношение-площади-кухни-к-общей.-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Cоотношение жилой и общей площади, а также отношение площади кухни к общей.</a></span></li><li><span><a href="#Выводы-по-расчетам-и-добавлению-новых-столбцов" data-toc-modified-id="Выводы-по-расчетам-и-добавлению-новых-столбцов-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Выводы по расчетам и добавлению новых столбцов</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изучение-параметров:-площадь,-цена,-число-комнат,-высота-потолков.-Построение-гистограммы-для-каждого-параметра." data-toc-modified-id="Изучение-параметров:-площадь,-цена,-число-комнат,-высота-потолков.-Построение-гистограммы-для-каждого-параметра.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Изучение параметров: площадь, цена, число комнат, высота потолков. Построение гистограммы для каждого параметра.</a></span><ul class="toc-item"><li><span><a href="#Площадь" data-toc-modified-id="Площадь-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Площадь</a></span></li><li><span><a href="#Цена" data-toc-modified-id="Цена-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Цена</a></span></li><li><span><a href="#Число-комнат" data-toc-modified-id="Число-комнат-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Число комнат</a></span></li><li><span><a href="#Высота-потолков" data-toc-modified-id="Высота-потолков-4.1.4"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span>Высота потолков</a></span></li></ul></li><li><span><a href="#Изучение-времени-продажи-квартиры" data-toc-modified-id="Изучение-времени-продажи-квартиры-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Изучение времени продажи квартиры</a></span></li><li><span><a href="#Чистка-редких-и-выбивающихся-значений." data-toc-modified-id="Чистка-редких-и-выбивающихся-значений.-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Чистка редких и выбивающихся значений.</a></span></li><li><span><a href="#Какие-факторы-больше-всего-влияют-на-стоимость-квартиры" data-toc-modified-id="Какие-факторы-больше-всего-влияют-на-стоимость-квартиры-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Какие факторы больше всего влияют на стоимость квартиры</a></span><ul class="toc-item"><li><span><a href="#Зависимость-цены-от-площади-квартиры" data-toc-modified-id="Зависимость-цены-от-площади-квартиры-4.4.1"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>Зависимость цены от площади квартиры</a></span></li><li><span><a href="#Зависимость-цены-от-числа-комнат-в-квартире" data-toc-modified-id="Зависимость-цены-от-числа-комнат-в-квартире-4.4.2"><span class="toc-item-num">4.4.2&nbsp;&nbsp;</span>Зависимость цены от числа комнат в квартире</a></span></li><li><span><a href="#Зависимость-цены-от-удалённости-от-центра" data-toc-modified-id="Зависимость-цены-от-удалённости-от-центра-4.4.3"><span class="toc-item-num">4.4.3&nbsp;&nbsp;</span>Зависимость цены от удалённости от центра</a></span></li><li><span><a href="#Зависимость-цены-от-того,-на-каком-этаже-расположена-квартира:-первом,-последнем-или-другом." data-toc-modified-id="Зависимость-цены-от-того,-на-каком-этаже-расположена-квартира:-первом,-последнем-или-другом.-4.4.4"><span class="toc-item-num">4.4.4&nbsp;&nbsp;</span>Зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом.</a></span></li><li><span><a href="#Зависимость-от-даты-размещения:-дня-недели,-месяца-и-года." data-toc-modified-id="Зависимость-от-даты-размещения:-дня-недели,-месяца-и-года.-4.4.5"><span class="toc-item-num">4.4.5&nbsp;&nbsp;</span>Зависимость от даты размещения: дня недели, месяца и года.</a></span></li></ul></li><li><span><a href="#Выберите-10-населённых-пунктов-с-наибольшим-числом-объявлений." data-toc-modified-id="Выберите-10-населённых-пунктов-с-наибольшим-числом-объявлений.-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Выберите 10 населённых пунктов с наибольшим числом объявлений.</a></span></li><li><span><a href="#Изучите-предложения-квартир" data-toc-modified-id="Изучите-предложения-квартир-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Изучите предложения квартир</a></span></li><li><span><a href="#Выделите-сегмент-квартир-в-центре." data-toc-modified-id="Выделите-сегмент-квартир-в-центре.-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Выделите сегмент квартир в центре.</a></span><ul class="toc-item"><li><span><a href="#Выделение-сегментов-по-центру-и-городу,-изучение:-площадь,-цена,-число-комнат,-высота-потолков" data-toc-modified-id="Выделение-сегментов-по-центру-и-городу,-изучение:-площадь,-цена,-число-комнат,-высота-потолков-4.7.1"><span class="toc-item-num">4.7.1&nbsp;&nbsp;</span>Выделение сегментов по центру и городу, изучение: площадь, цена, число комнат, высота потолков</a></span></li><li><span><a href="#Сравнение-Центра-города-с-Общей-базой" data-toc-modified-id="Сравнение-Центра-города-с-Общей-базой-4.7.2"><span class="toc-item-num">4.7.2&nbsp;&nbsp;</span>Сравнение Центра города с Общей базой</a></span></li></ul></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекc Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# **Цель исследования**
# Научиться определять рыночную стоимость объектов недвижимости.
#
# **Данные**
# Файл с данными *(real_estate_data.csv)* сервиса Яндекс Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет.
#
# **Задача**
# Необходимо установить параметры для построения автоматизированной системы, которая отследит аномалии и мошенническую деятельность.
#
# **Описание данных**
#
# airports_nearest — расстояние до ближайшего аэропорта в метрах (м)
#
# balcony — число балконов
#
# ceiling_height — высота потолков (м)
#
# cityCenters_nearest — расстояние до центра города (м)
#
# days_exposition — сколько дней было размещено объявление (от публикации до снятия)
#
# first_day_exposition — дата публикации
#
# floor — этаж
#
# floors_total — всего этажей в доме
#
# is_apartment — апартаменты (булев тип)
#
# kitchen_area — площадь кухни в квадратных метрах (м²)
#
# last_price — цена на момент снятия с публикации
#
# living_area — жилая площадь в квадратных метрах (м²)
#
# locality_name — название населённого пункта
#
# open_plan — свободная планировка (булев тип)
#
# parks_around3000 — число парков в радиусе 3 км
#
# parks_nearest — расстояние до ближайшего парка (м)
#
# ponds_around3000 — число водоёмов в радиусе 3 км
#
# ponds_nearest — расстояние до ближайшего водоёма (м)
#
# rooms — число комнат
#
# studio — квартира-студия (булев тип)
#
# total_area — площадь квартиры в квадратных метрах (м²)
#
# total_images — число фотографий квартиры в объявлении

# %% [markdown]
# ## Изучение данных из файла

# %% [markdown]
# Импортируем библиотеки pandas, numpy и matplotlib.pyplot для работы с данными.
# Читаем файл с исходными данными, датафрейм сохраняем в переменную data, в качестве параметра разделителя используем табуляцию.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

# %%
data = pd.read_csv("/datasets/real_estate_data.csv", sep="\t")

# %% [markdown]
# Изучаем общую информацию о данных с помощью методов .info() и .head().

# %%
display(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
display(data.head())
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# <div style="border:solid purple 2px; padding: 20px">Датафрейм состоит из 22 колонок и 23699 строк
#
# **СТОЛБЕЦ, кроме анализа значений и проверки на дубликаты:**
#
# **total_images** (23699 non-null int64) - корректен
#
# **last_price** (23699 non-null *float64 - заменить*) - корректен
#
# **total_area** (23699 non-null float64) - корректен
#
# **first_day_exposition** (23699 non-null *object - заменить*) - корректен
#
# **rooms** (23699 non-null int64) - корректен
#
# **ceiling_height** (*14504 - 38,8 % пропусков* non-null *float64 - заменить*) - требует работы с пропусками
#
# **floors_total** (*23613 - 86 пропущенных значений* non-null *float64 - заменить*) - требует работы с пропусками и доп.анализа
#
# **living_area** (*21796 - 8% пропусков* non-null float64) - требует работы с пропусками
#
# **floor** (23699 non-null int64) - корректен
#
# **is_apartment** (*2775 - 88.3% пропусков* non-null object) - требует работы с пропусками
#
# **studio** (23699 non-null bool) - корректен
#
# **open_plan** (23699 non-null bool) - корректен
#
# **kitchen_area** (*21421 - 9,6% пропусков* non-null float64) - требует работы с пропусками
#
# **balcony** (*12180 - 48,6% пропусков* non-null float64) - требует работы с пропусками
#
# **locality_name** (*23650 - 49 пропусков* non-null object) - требует работы с пропусками и доп.анализа
#
# **airports_nearest** (*18157 - 23,4% пропусков* non-null *float64 - заменить*) - требует работы с пропусками
#
# **cityCenters_nearest** (*18180 - 23,3% пропусков* non-null *float64 - заменить*) - требует приведения названия столбца к "змеиному регистру", а также работы с пропусками
#
# **parks_around3000** (*18181 - 23,3% пропусков* non-null *float64 - заменить*) - требует работы с пропусками
#
# **parks_nearest**  (*8079 - 65,9% пропусков* non-null *float64 - заменить*) - требует работы с пропусками
#
# **ponds_around3000** (*18181 - 23,3% пропусков*  non-null *float64 - заменить*) - требует работы с пропусками
#
# **ponds_nearest**  (*9110 - 65,5% пропусков* non-null *float64 - заменить*) - требует работы с пропусками
#
# **days_exposition** (*20518 - 13,4% пропусков* non-null *float64 - заменить*) - требует работы с пропусками

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Работа с пропусками и изменением типов данных

# %% [markdown]
# ####  total_images (23699 non-null int64)
# **Число фотографий квартиры в объявлении**

# %% [markdown]
# Изучаем  информацию о количественных данных столбца, визуализируем гистограммой

# %%
data['total_images'].value_counts()
# Out:
# 10    1798
# 9     1725
# 20    1694
# 8     1585
# 7     1521
# 6     1482
# 11    1362
# 5     1301
# 12    1225
# 0     1059
# 13    1015
# 4      986
# 14     986
# 15     948
# 1      872
# 3      769
# 16     761
# 17     650
# 18     642
# 2      640
# 19     603
# 23      16
# 21      12
# 24       8
# 22       8
# 26       5
# 28       4
# 32       4
# 29       3
# 50       3
# 27       2
# 35       2
# 30       2
# 31       2
# 39       1
# 25       1
# 42       1
# 37       1
# Name: total_images, dtype: int64

# %%
data['total_images'].hist(bins=50, range=(1,50))
# Out:
# <AxesSubplot:>

# %% [markdown]
# <div style="border:solid purple 2px; padding: 20px">  <b>Вывод 2.1.1:</b>
# Данные по числу фотографий квартиры в объявлении корректны, похожи на правду.</div>

# %% [markdown]
# ####  last_price (23699 non-null *float64 - заменить*)
# **Цена на момент снятия с публикации**

# %% [markdown]
#
# Изменим тип данных столбца на int и изучим описательную статистику выборки</div>

# %%
data['last_price'] = data['last_price'].astype(int)
data['last_price'].describe()
# Out:
# count    2.369900e+04
# mean     6.541549e+06
# std      1.088701e+07
# min      1.219000e+04
# 25%      3.400000e+06
# 50%      4.650000e+06
# 75%      6.800000e+06
# max      7.630000e+08
# Name: last_price, dtype: float64

# %%
data['last_price'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# Поскольку видим разброс данных от ~12 тыс.руб до 763 млн. руб., есть смысл разбить графики по следующим диапазонам:
#     от 0 до 800 000 руб.
#     от 800 001 до 80 000 000 руб.
#     от 80 000 0001 до 800 000 000 руб.
#     и изучить данные на графиках (размер корзины примем за 100).</div>

# %%
data.hist('last_price', bins=100, figsize=(10,5), range=(0, 800000))
# Out:
# array([[<AxesSubplot:title={'center':'last_price'}>]], dtype=object)

# %% [markdown]
#  Замечаем аномальные значения. В данной выборке можно отбросить значения менее 400 тыс.руб.</div>

# %%
data.hist('last_price', bins=100, figsize=(10,5), range=(800001, 80000000))
# Out:
# array([[<AxesSubplot:title={'center':'last_price'}>]], dtype=object)

# %%
data.hist('last_price', bins=100, figsize=(10,5), range=(80000000, 800000000))
# Out:
# array([[<AxesSubplot:title={'center':'last_price'}>]], dtype=object)

# %% [markdown]
#  Также можно отбросить редкие аномалии (более 100 млн.руб). Удалим их, перезаписав индексы в исходном датафрейме, удалив старую индексацию</div>

# %%
data = data.loc[(data['last_price']>400000) & (data['last_price']<100000000)]
data.reset_index(inplace=True, drop=True)

# %% [markdown]
# Проверим результат, выведем 10 последних строк таблицы и посмотрим индексацию </div>

# %%
data.tail(10)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 23651            13     3550000       35.30  2018-02-28T00:00:00      1
# 23652             3     5500000       52.00  2018-07-19T00:00:00      2
# 23653            11     9470000       72.90  2016-10-13T00:00:00      2
# 23654             2     1350000       30.00  2017-07-07T00:00:00      1
# 23655             9     4600000       62.40  2016-08-05T00:00:00      3
# 23656             9     9700000      133.81  2017-03-21T00:00:00      3
# 23657            14     3100000       59.00  2018-01-15T00:00:00      3
# 23658            18     2500000       56.70  2018-02-11T00:00:00      2
# 23659            13    11475000       76.75  2017-03-28T00:00:00      2
# 23660             4     1350000       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 23651            2.86          15.0         16.3      4          NaN  ...
# ...

# %%
data.index
# Out:
# RangeIndex(start=0, stop=23661, step=1)

# %% [markdown]
# <div style="border:solid purple 2px; padding: 20px"> <b>Вывод 2.1.2:</b> Столбец с ценой на момент снятия публикации обработан на выдающиеся значения, всего удалено 23699-23661=38 строк </div>

# %% [markdown]
# ####  total_area (23699 non-null float64)
# **Площадь квартиры в кадратных метрах (м2)**

# %% [markdown]
#  Произведем анализ аналогично с п.2.1.2 </div>

# %%
data['total_area'].describe()
# Out:
# count    23661.000000
# mean        59.925974
# std         33.470704
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.600000
# max        590.000000
# Name: total_area, dtype: float64

# %% [markdown]
# Разброс данных похож на реальный - от 12 м2(может продаваться комната) до 590 м2. Для наглядности разобьем графики на диапазоны:
#     от 0 до 100 м2.
#     от 100 до 300 м2.
#     от 300 до 600 м2.
#     и изучить распределение на графиках (размер корзины примем за 100).</div>

# %%
data.hist('total_area', bins=100, figsize=(10,5), range=(0, 100))
# Out:
# array([[<AxesSubplot:title={'center':'total_area'}>]], dtype=object)

# %%
data.hist('total_area', bins=100, figsize=(10,5), range=(100, 300))
# Out:
# array([[<AxesSubplot:title={'center':'total_area'}>]], dtype=object)

# %%
data.hist('total_area', bins=100, figsize=(10,5), range=(300, 600))
# Out:
# array([[<AxesSubplot:title={'center':'total_area'}>]], dtype=object)

# %% [markdown]
#  <div style="border:solid purple 2px; padding: 20px"><b>Вывод 2.1.3:</b>
# Медиана выборки близка к среднему значению, что характеризует распределение, как нормальное. Также на графиках мы вижим равномерное распределение. Столбец корректен, выбросы не зафиксированы</div>

# %% [markdown]
# ####  first_day_exposition (23699 non-null object - заменить)
# **Дата публикации**

# %% [markdown]
# Изучаем данные столбца</div>

# %%
data['first_day_exposition'].head()
# Out:
# 0    2019-03-07T00:00:00
# 1    2018-12-04T00:00:00
# 2    2015-08-20T00:00:00
# 3    2015-07-24T00:00:00
# 4    2018-06-19T00:00:00
# Name: first_day_exposition, dtype: object

# %%
data['first_day_exposition'].describe()
# Out:
# count                   23661
# unique                   1490
# top       2018-02-01T00:00:00
# freq                      368
# Name: first_day_exposition, dtype: object

# %% [markdown]
# Заменим формат записи даты и проверим результат</div>

# %%
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')

# %%
data['first_day_exposition'].head()
# Out:
# 0   2019-03-07
# 1   2018-12-04
# 2   2015-08-20
# 3   2015-07-24
# 4   2018-06-19
# Name: first_day_exposition, dtype: datetime64[ns]

# %%
data['first_day_exposition'].describe()
# Out:
# /tmp/ipykernel_53/546544682.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   data['first_day_exposition'].describe()
# count                   23661
# unique                   1490
# top       2018-02-01 00:00:00
# freq                      368
# first     2014-11-27 00:00:00
# last      2019-05-03 00:00:00
# Name: first_day_exposition, dtype: object

# %% [markdown]
#  <div style="border:solid purple 2px; padding: 20px"> <b>Вывод 2.1.4:</b>
# Формат даты исправлен, удобен для дальнейшей работы</div>

# %% [markdown]
# ####  rooms (23699 non-null int64)
# **Количество комнат**

# %% [markdown]
# Изучаем  информацию о количественных данных столбца, визуализируем гистограммой.</div>

# %%
data['rooms'].value_counts()
# Out:
# 1     8047
# 2     7938
# 3     5810
# 4     1171
# 5      316
# 0      197
# 6      100
# 7       54
# 8       10
# 9        8
# 10       3
# 11       2
# 14       2
# 16       1
# 19       1
# 15       1
# Name: rooms, dtype: int64

# %% [markdown]
# Видим артефакты: если теоретически даже 16 комнат может иметь место, то 0 (197 квартир) быть не может. Определим площади, относящиеся к "ноль-комнатным" квартирам. Для этого сделаем срез для таких квартир по столбцу с площадью в м2 и изучим статистические характеристики </div>

# %%
print(data.query('rooms == 0')['total_area'].describe())
# Out:
# count    197.000000
# mean      29.279746
# std       25.855264
# min       15.500000
# 25%       24.050000
# 50%       26.050000
# 75%       28.400000
# max      371.000000
# Name: total_area, dtype: float64

# %% [markdown]
# Замечаем, что большинство значений, ограниченные третьим квартилем, менее 30 м2 (ориентируемся, что это однокомнатные). Также видим максимальное значение в 371 м2. Нужно определиться, какие еще большие значения входят в выборку. Сделаем срез "ноль-комнатных" квартир по значениям площади выше третьего квартиля по убыванию </div>

# %%
data.query('rooms==0 and total_area>28.4')['total_area'].sort_values(ascending=False)
# Out:
# 19363    371.00
# 20051     98.40
# 3449      73.60
# 21193     71.00
# 13594     58.40
# 9992      44.20
# 15296     43.30
# 7226      42.63
# 16106     42.10
# 9036      38.30
# 4674      35.00
# 838       35.00
# 508       34.40
# 21594     34.00
# 16495     32.80
# 18104     32.50
# 12213     32.40
# 6997      32.30
# 15680     32.20
# 15690     32.03
# 1172      32.00
# 6209      32.00
# 17778     31.10
# 1523      31.00
# 15732     31.00
# 17926     31.00
# 18000     31.00
# 3138      31.00
# 13849     31.00
# 6794      31.00
# 19705     30.50
# 5947      30.30
# 22017     30.10
# 22829     30.00
# 7275      30.00
# 1595      30.00
# 4962      29.30
# 7245      29.20
# 10400     29.10
# 19846     29.00
# 12973     29.00
# 18521     29.00
# 15688     29.00
# 3426      29.00
# 2049      29.00
# 1171      29.00
# 23554     29.00
# 2983      28.90
# 21265     28.50
# Name: total_area, dtype: float64

# %% [markdown]
# Значение 371 м2 удалим, как очевидный выброс (тут же выброс, да?=)). Остальные значения распределим по одно-, двух-, трех- и четырехкомнатным квартирам. Для этого сначала определим среднее значение площади для каждой из типов квартир </div>

# %%
for i in range(1,5):
    display (f'{i}-комнатная квартира, cредняя площадь (м2):',data.query('rooms == @i')['total_area'].mean())
# Out:
# '1-комнатная квартира, cредняя площадь (м2):'
# 37.64466882067852
# '2-комнатная квартира, cредняя площадь (м2):'
# 55.83181027966743
# '3-комнатная квартира, cредняя площадь (м2):'
# 77.68576075731498
# '4-комнатная квартира, cредняя площадь (м2):'
# 106.41784799316824

# %% [markdown]
# Удалим выброс 371 м2 из выборки, проверим результат </div>

# %%
display('Cтрок до удаления выброса', len(data))
# Out:
# 'Cтрок до удаления выброса'
# 23661

# %%
data.drop(data.loc[(data['rooms']==0) & (data['total_area']==371)].index,inplace=True, axis=0)

# %%
display('Строк после удаления', len(data))
# Out:
# 'Строк после удаления'
# 23660

# %% [markdown]
# На основании средних площадей, можем распределить типы квартир по следующим диапазонам м2: однокомнатные - менее 40 м2, двухкомнатные - от 40 (включительно) до 60 м2, трехкомнатные - от 60 (включительно) до 80 м2, все остальное - четырехкомнатные. Заменим пропуски данных подходящими им значениями</div>

# %%
data.loc[(data['rooms']==0) & (data['total_area']<40), 'rooms'] = 1
data.loc[(data['rooms']==0) & (data['total_area']>=40) & (data['total_area']<60), 'rooms'] = 2
data.loc[(data['rooms']==0) & (data['total_area']>=60) & (data['total_area']<80), 'rooms'] = 3
data.loc[(data['rooms']==0) & (data['total_area']>=80), 'rooms'] = 4

# %% [markdown]
# Проверяем </div>

# %%
data['rooms'].value_counts()
# Out:
# 1     8235
# 2     7943
# 3     5812
# 4     1172
# 5      316
# 6      100
# 7       54
# 8       10
# 9        8
# 10       3
# 11       2
# 14       2
# 16       1
# 19       1
# 15       1
# Name: rooms, dtype: int64

# %% [markdown]
#  <div style="border:solid purple 2px; padding: 20px"><b>Вывод 2.1.5:</b>
# Таким образом, видим: однокомнатные - 8047/8235 (188), двухкомнатные - 7938/7943 (5), трехкомнатные - 5810/5812 (2), четырехкомнатные - 1171/1172 (1). Итого 196 значений "ноль-комнатных" квартир распределено по квартирам других типов, а одно значение в 371 м2 удалено </div>

# %% [markdown]
# ####  ceiling_height (14504 - 38,8 % пропусков non-null float64 - заменить
# Высота потолков

# %% [markdown]
# Изучаем  информацию о количественных данных столбца, визуализируем гистограммой.</div>

# %%
data['ceiling_height'].value_counts()
# Out:
# 2.50     3515
# 2.60     1646
# 2.70     1574
# 3.00     1110
# 2.80      992
#          ...
# 22.60       1
# 3.76        1
# 5.20        1
# 2.89        1
# 4.65        1
# Name: ceiling_height, Length: 180, dtype: int64

# %%
data['ceiling_height'].describe()
# Out:
# count    14477.000000
# mean         2.769807
# std          1.261218
# min          1.000000
# 25%          2.510000
# 50%          2.650000
# 75%          2.800000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# По данным [Яндекс.Кью](https://yandex.ru/q/question/kakaia_vysota_potolkov_v_novostroikakh_d2d676be/) высота потолков в новостройках не может быть меньше 250 сантиметров. Обычно это значение колеблется в пределах 260-290 см, в элитных жилых комплексах высота потолков может превышать 400 см. Но поскольку в нашем исследовании мы имеем дело также и со вторичным жилым фондом, то ремонт (натяжные/гипсокартонные потолки) или иные факторы призывают нас принять нормальной высоту потолка от 2,3 м. Проанализируем, разобьем данные на диапазоны и посмотрим на графики. </div>

# %%
data['ceiling_height'].hist(figsize=(10,5), bins=50, range=(0, 2.3))
# Out:
# <AxesSubplot:>

# %%
data['ceiling_height'].hist(figsize=(10,5), bins=50, range=(2.3, 4.5))
# Out:
# <AxesSubplot:>

# %%
data['ceiling_height'].hist(figsize=(10,5), bins=50, range=(4.5, 100))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Рассмотрим подробнее строки, соответствующие высоте потолков от 19 до 35 метров. Возможно, здесь пропущена запятая в значениях, тогда просто разделим на 10. Значение в 100 метров даже в таком раскладе нам не подходит, его не рассматриваем. Также нас не интересуют строки со значениями от 7 до 9 (возможно, промплощади или многоуровневые квартиры), а также цокольные этажи (менее 1,9 метров и от 10 до 19 - по аналогии со 100 - отнесем к цоколям) - все эти значения удалим. Но для начала обработаем интервал (19, 35), для этого возьмем срез: </div>

# %%
display(data.query('19 < ceiling_height < 35'))
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 355              17     3600000        55.2           2018-07-12      2
# 3139             14     2900000        75.0           2018-11-12      3
# 4634              0     4300000        45.0           2018-02-01      2
# 4867              7     3000000        25.0           2017-09-27      1
# 5066              0     3850000        30.5           2018-10-03      1
# 5236              0     2500000        54.0           2017-10-13      2
# 5659              4     4400000        50.0           2017-08-08      2
# 5797             17     8150000        80.0           2019-01-09      2
# 6235              6     3300000        44.4           2019-03-25      2
# 9363              5     3950000        42.0           2017-03-26      3
# 10757             8     3800000        58.0           2017-10-13      2
# 11269             0     1950000        37.0           2019-03-20      1
# ...

# %% [markdown]
# Получили таблицу по 22 значениям. Исходя из значений площади и цены, делаем вывод, что мы были правы - квартиры не уникальны, а значит пропущена запятая. Исправим это. </div>

# %%
ind_list = data.query('19 < ceiling_height < 35').index
data.loc[ind_list, 'ceiling_height'] = data.loc[ind_list, 'ceiling_height'] / 10

# %%
data.loc[ind_list]['ceiling_height']
# Out:
# 355      2.50
# 3139     3.20
# 4634     2.50
# 4867     2.70
# 5066     2.40
# 5236     2.70
# 5659     2.60
# 5797     2.70
# 6235     2.50
# 9363     2.50
# 10757    2.70
# 11269    2.50
# 14361    2.50
# 17469    2.00
# 17830    2.70
# 18517    2.50
# 20445    2.70
# 20474    2.26
# 21343    2.75
# 21790    2.70
# 22299    3.20
# 22900    2.70
# Name: ceiling_height, dtype: float64

# %%
data['ceiling_height'].head(10)
# Out:
# 0    2.70
# 1     NaN
# 2     NaN
# 3     NaN
# 4    3.03
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9    2.50
# Name: ceiling_height, dtype: float64

# %%
data['ceiling_height'].tail(10)
# Out:
# 23651    2.86
# 23652     NaN
# 23653    2.75
# 23654     NaN
# 23655    2.60
# 23656    3.70
# 23657     NaN
# 23658     NaN
# 23659    3.00
# 23660    2.50
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Удалим строки с некорректными значениями (ниже 1.9, от 7.0 до 19.0, выше 35.0). Возьмем срез, поместим его в список индексов:  </div>

# %%
ind_list = data.query('ceiling_height<1.9 or 7<ceiling_height<19 or ceiling_height>35').index
data.loc[ind_list, 'ceiling_height']
# Out:
# 3465       8.00
# 5702       1.20
# 5853       8.30
# 15038     14.00
# 15719      8.00
# 16907      1.75
# 17415      8.00
# 22272     10.30
# 22553      1.00
# 22831    100.00
# Name: ceiling_height, dtype: float64

# %% [markdown]
#  Проверим количество строк до удаления, удалим аномалии, и проверим количество строк после удаления, приведем в порядок индексы: </div>

# %%
display('Строк до удаления аномалий:', len(data))
# Out:
# 'Строк до удаления аномалий:'
# 23660

# %%
data.drop(ind_list, inplace=True, axis=0)

# %%
display('Строк после удаления аномалий:', len(data))
# Out:
# 'Строк после удаления аномалий:'
# 23650

# %% [markdown]
#  Аномалии у нас занимали 10 строк, это немного, ими легко можно пожертвовать без искажения результата </div>

# %%
data.reset_index(inplace=True, drop=True)
data.tail(10)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 23640            13     3550000       35.30           2018-02-28      1
# 23641             3     5500000       52.00           2018-07-19      2
# 23642            11     9470000       72.90           2016-10-13      2
# 23643             2     1350000       30.00           2017-07-07      1
# 23644             9     4600000       62.40           2016-08-05      3
# 23645             9     9700000      133.81           2017-03-21      3
# 23646            14     3100000       59.00           2018-01-15      3
# 23647            18     2500000       56.70           2018-02-11      2
# 23648            13    11475000       76.75           2017-03-28      2
# 23649             4     1350000       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 23640            2.86          15.0         16.3      4          NaN  ...
# ...

# %% [markdown]
# Займёмся пропусками, посчитаем их: </div>

# %%
display('Всего пропусков:', data['ceiling_height'].isna().sum())
# Out:
# 'Всего пропусков:'
# 9183

# %% [markdown]
# Пропусков у нас много. Лучшим решением в данном случае будет заменить пропущенные значения медианным значением выборки, посмотрим статистические характеристики по столбцу и сделаем соответвтвующую замену: </div>

# %%
data['ceiling_height'] = data['ceiling_height'].fillna(2.65)

# %%
display('Пропусков после замены на медиану:', data['ceiling_height'].isna().sum())
# Out:
# 'Пропусков после замены на медиану:'
# 0

# %% [markdown]
# </b> Пропуски заменены, теперь, чтобы заменить на целочисленный тип без проблем, перезапишем метры в сантиметры. И поменяем тип. </div>

# %%
data['ceiling_height'] = data['ceiling_height'] * 100
print(data['ceiling_height'].describe())
# Out:
# count    23650.000000
# mean       269.578478
# std         21.742051
# min        200.000000
# 25%        260.000000
# 50%        265.000000
# 75%        270.000000
# max        580.000000
# Name: ceiling_height, dtype: float64

# %%
data['ceiling_height'] = data['ceiling_height'].astype('int')

# %%
data['ceiling_height'].dtype
# Out:
# dtype('int64')

# %%
data.tail(10)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 23640            13     3550000       35.30           2018-02-28      1
# 23641             3     5500000       52.00           2018-07-19      2
# 23642            11     9470000       72.90           2016-10-13      2
# 23643             2     1350000       30.00           2017-07-07      1
# 23644             9     4600000       62.40           2016-08-05      3
# 23645             9     9700000      133.81           2017-03-21      3
# 23646            14     3100000       59.00           2018-01-15      3
# 23647            18     2500000       56.70           2018-02-11      2
# 23648            13    11475000       76.75           2017-03-28      2
# 23649             4     1350000       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 23640             286          15.0         16.3      4          NaN  ...
# ...

# %% [markdown]
# <div style="border:solid purple 2px; padding: 20px"> <b>Вывод 2.1.6:</b> Все операции по предобработке данных в столбце с высотой потолка завершены, ура =). </div>

# %% [markdown]
# ####  floors_total (23613 - 86 пропущенных значений non-null float64 - заменить)
# **Всего этажей в доме**

# %% [markdown]
#
# Изучаем  информацию о количественных данных столбца, визуализируем гистограммой.</div>

# %%
data['floors_total'].value_counts()
# Out:
# 5.0     5779
# 9.0     3757
# 16.0    1373
# 12.0    1361
# 4.0     1195
# 10.0    1173
# 25.0    1073
# 6.0      907
# 17.0     833
# 3.0      667
# 7.0      583
# 14.0     552
# 18.0     505
# 24.0     469
# 8.0      386
# 2.0      382
# 15.0     365
# 23.0     352
# 19.0     339
# 22.0     286
# 20.0     271
# 13.0     229
# 11.0     203
# 27.0     164
# 21.0     158
# 26.0     124
# 1.0       25
# 35.0      24
# 28.0      21
# 36.0       3
# 29.0       1
# 60.0       1
# 52.0       1
# 34.0       1
# 33.0       1
# Name: floors_total, dtype: int64

# %%
data['floors_total'].describe()
# Out:
# count    23564.000000
# mean        10.678450
# std          6.597075
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         60.000000
# Name: floors_total, dtype: float64

# %%
data['floors_total'].hist(figsize=(10,5), bins=50, range=(1, 60))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Данные распределены правдоподобно, нулевых и аномальных значений нет. Изучим пропуски:</div>

# %%
data['floors_total'].isna().sum()
# Out:
# 86

# %%
data.query('floors_total.isna()').head()
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 186             12    11640000        65.2           2018-10-02      2
# 237              4     2438033        28.1           2016-11-23      1
# 457              4     9788348        70.8           2015-08-01      2
# 671              4     6051191        93.6           2017-04-06      3
# 1752             5     3600000        39.0           2017-04-22      1
#
#       ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 186              265           NaN        30.80      4          NaN  ...
# 237              265           NaN        20.75      1          NaN  ...
# 457              265           NaN        38.40     12          NaN  ...
# 671              265           NaN        47.10      8          NaN  ...
# 1752             265           NaN          NaN      9          NaN  ...
#
#       kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
#
# Пропущенных значений 86, это немного. Но чтобы не упускать их из виду, рассмотрим их в соотношении со столбцом этажа квартиры (floor). Самые распростаненные по этажности типы домов: пяти-, девяти-, двеннадцати-, шестнадцатиэтажные и остальные(многоэтажки/небоскребы). Таким образом, если:
#
#     floor от 1 до 5, то пропуск заменяем на 5-этажный дом,
#     floor от 6 до 9, то пропуск заменяем на 9-этажный дом,
#     floor от 10 до 12, то пропуск заменяем на 12-этажный дом,
#     floor от 13 до 16, то пропуск заменяем на 16-этажный дом,
#     floor выше 16, то пропуск заменяем на значение этажа продаваемой квартиры + 1 этаж
#
#
# </div>

# %%
data.loc[data.query('floors_total.isna() and 1<=floor<=5').index, 'floors_total'] = 5
data.loc[data.query('floors_total.isna() and 6<=floor<=9').index, 'floors_total'] = 9
data.loc[data.query('floors_total.isna() and 10<=floor<=12').index, 'floors_total'] = 12
data.loc[data.query('floors_total.isna() and 13<=floor<=16').index, 'floors_total'] = 16
data.loc[data.query('floors_total.isna() and floor>16').index, 'floors_total'] = data['floor']+1

# %%
data['floors_total'].value_counts().head(10)
# Out:
# 5.0     5802
# 9.0     3783
# 16.0    1381
# 12.0    1373
# 4.0     1195
# 10.0    1173
# 25.0    1075
# 6.0      907
# 17.0     833
# 3.0      667
# Name: floors_total, dtype: int64

# %%
data['floors_total'].isna().sum()
# Out:
# 0

# %% [markdown]
# Пропуски заменены, изменим тип данных на int</div>

# %%
data['floors_total'] = data['floors_total'].astype('int')
data['floors_total'].dtype
# Out:
# dtype('int64')

# %%
data.tail(10)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 23640            13     3550000       35.30           2018-02-28      1
# 23641             3     5500000       52.00           2018-07-19      2
# 23642            11     9470000       72.90           2016-10-13      2
# 23643             2     1350000       30.00           2017-07-07      1
# 23644             9     4600000       62.40           2016-08-05      3
# 23645             9     9700000      133.81           2017-03-21      3
# 23646            14     3100000       59.00           2018-01-15      3
# 23647            18     2500000       56.70           2018-02-11      2
# 23648            13    11475000       76.75           2017-03-28      2
# 23649             4     1350000       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 23640             286            15         16.3      4          NaN  ...
# ...

# %% [markdown]
#  <div style="border:solid purple 2px; padding: 20px"><b>Вывод 2.1.7:</b> Предобработка столбца с этажностью дома завершена, 86 пропущенных значений заменены без потери результата. </div>

# %% [markdown]
# ####  living_area (21796 - 8% пропусков non-null float64) - требует работы с пропусками
# **Жилая площадь**

# %% [markdown]
# Изучаем  информацию о количественных и статистических данных столбца, визуализируем гистограммой.</div>

# %%
data['living_area'].value_counts()
# Out:
# 18.00    882
# 17.00    675
# 30.00    598
# 16.00    486
# 20.00    481
#         ...
# 35.77      1
# 96.40      1
# 50.26      1
# 43.81      1
# 16.74      1
# Name: living_area, Length: 1769, dtype: int64

# %%
data['living_area'].describe()
# Out:
# count    21753.000000
# mean        34.256274
# std         21.178600
# min          2.000000
# 25%         18.600000
# 50%         30.000000
# 75%         42.200000
# max        409.000000
# Name: living_area, dtype: float64

# %% [markdown]
# Замечаем аномально малую жилую площадь, скорее всего здесь забыли дописать 0 или упустили десяток.</div>

# %%
data['living_area'].hist(figsize=(10,5), bins=50, range=(1, 410))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Данные распределены равномерно, однако, хорошо бы рассмотреть зависимость жилой площади от общей площади в квартире, которую мыобработали в п 2.1.3. Построим диаграмму рассеяния и оценим на правдоподобность</div>

# %%
data.plot(x='total_area', y='living_area', kind='scatter', figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='total_area', ylabel='living_area'>

# %% [markdown]
#  В целом, зависимость прямая, однако даже на таком графике видны несоответствия общей и жилой площадей. Проверим те жилые площади, которые меньше 10м2. Если несоответствия будут ощутимыми, заменим их на +10 м2</div>

# %%
index_list = data.loc[(data['living_area']<10) , ['living_area', 'total_area']].index
data.loc[index_list, ['living_area', 'total_area', 'rooms']]
# Out:
#        living_area  total_area  rooms
# 114            8.3       21.40      1
# 680            9.0       43.00      1
# 1322           9.0       52.00      2
# 2302           8.4       62.40      2
# 3233           3.0       41.00      1
# 4090           9.0       34.80      1
# 4532           9.0       18.00      1
# 7298           9.0       27.00      2
# 8308           9.0       52.00      2
# 13891          2.0       52.00      2
# 15804          9.0       33.00      1
# 16402          6.0       31.00      1
# 17215          8.9       33.00      1
# 17548          5.0       22.00      1
# 19215          6.5       33.00      1
# 19582          9.0       33.00      1
# 20953          8.0       50.60      2
# 21463          8.5       35.30      1
# 21716          2.0       23.00      1
# 21866          9.8       46.30      1
# 21900          5.4       77.60      4
# 22207          9.0       37.40      1
# 22427          9.1       33.26      2
# 23159          8.0       37.00      1
# ...

# %%
data.loc[(data['living_area']<10), 'living_area'] +=10 
data.loc[index_list, ['living_area', 'total_area', 'rooms']].head()
# Out:
#       living_area  total_area  rooms
# 114          18.3        21.4      1
# 680          19.0        43.0      1
# 1322         19.0        52.0      2
# 2302         18.4        62.4      2
# 3233         13.0        41.0      1

# %% [markdown]
#  Теперь данные по метражу жилой площади похожи на правду</div>

# %%
data.loc[:,['total_area', 'living_area']]
# Out:
#        total_area  living_area
# 0          108.00         51.0
# 1           40.40         18.6
# 2           56.00         34.3
# 3          159.00          NaN
# 4          100.00         32.0
# ...           ...          ...
# 23645      133.81         73.3
# 23646       59.00         38.0
# 23647       56.70         29.7
# 23648       76.75          NaN
# 23649       32.30         12.3
#
# [23650 rows x 2 columns]

# %%
display('Пропущенных значений по жилой площади:')
data['living_area'].isna().sum()
# Out:
# 'Пропущенных значений по жилой площади:'
# 1897

# %% [markdown]
# Посчитали количество пропущенных значений по жилой площади (1897). Заполним пропуски медианными значениями living_area в зависимости от total_area, так как, чем больше общая площадь, тем больше площадь жилая, и тем больше доля другой площади (вспомогательные помещения за исключением балкона).</div>

# %%
display('Квартир всего:')
len(data['total_area'])
# Out:
# 'Квартир всего:'
# 23650

# %%
ratio_living_area = data.loc[(data['living_area'].isna() == False), 'living_area'] / data.loc[(data['total_area'].isna() == False), 'total_area']
ratio_living_area_median = ratio_living_area.dropna().median()
ratio_living_area_mean = ratio_living_area.dropna().mean()

# %%
display('Медиана жилой площади:')
ratio_living_area_median
# Out:
# 'Медиана жилой площади:'
# 0.5680473372781065

# %%
display('Среднее жилой площади:')
ratio_living_area_mean
# Out:
# 'Среднее жилой площади:'
# 0.5651157186380041

# %% [markdown]
# Поскольку медианное и среднее значения практически равны, выберем медиану и присвоим ее значение доле</div>

# %%
ratio_living_area = ratio_living_area_median

# %% [markdown]
# Создадим список для индексов, где есть пропуски в значениях living_area </div>

# %%
index_non_living = data.loc[(data['living_area'].isna() == True)].index 
data.loc[index_non_living, 'living_area'] = ratio_living_area * data.loc[index_non_living, 'total_area']

# %%
data['living_area'].isna().sum()
# Out:
# 0

# %%
data['living_area'].describe()
# Out:
# count    23650.000000
# mean        34.352145
# std         21.277707
# min          7.384615
# 25%         19.000000
# 50%         30.000000
# 75%         42.026627
# max        409.000000
# Name: living_area, dtype: float64

# %%
data['total_area'].describe()
# Out:
# count    23650.000000
# mean        59.918701
# std         33.415186
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.600000
# max        590.000000
# Name: total_area, dtype: float64

# %% [markdown]
#  <div style="border:solid purple 2px; padding: 20px"><b>Вывод 2.1.8:</b> Заполнили все пропуски в столбце с жилой площадью в зависимости от общей, справились с артефактами. Даже после замены пропущенных значений получили минимальные значений жилой менее 10 м2, но это не противоречит минимальному заначению столбца общей площади </div>

# %% [markdown]
# ####  floor (23699 non-null int64) - корректен
# **Этаж**

# %% [markdown]
# Изучаем  информацию о количественных и статистических данных столбца. </div>

# %%
data['floor'].value_counts()
# Out:
# 2     3363
# 3     3067
# 1     2914
# 4     2796
# 5     2612
# 6     1303
# 7     1210
# 8     1081
# 9     1050
# 10     686
# 12     526
# 11     523
# 13     379
# 15     342
# 14     336
# 16     315
# 17     227
# 18     178
# 19     147
# 21     125
# 22     113
# 20     110
# 23     100
# 24      63
# 25      44
# 26      24
# 27      10
# 28       1
# 29       1
# 32       1
# 30       1
# 33       1
# 31       1
# Name: floor, dtype: int64

# %%
data['floor'].describe()
# Out:
# count    23650.000000
# mean         5.892304
# std          4.885300
# min          1.000000
# 25%          2.000000
# 50%          4.000000
# 75%          8.000000
# max         33.000000
# Name: floor, dtype: float64

# %% [markdown]
#  <div style="border:solid purple 2px; padding: 20px"><b>Вывод 2.1.9:</b>
# Столбец корректен! Ура-2 =) </div>

# %% [markdown]
# ####  is_apartment (2775 - 88.3% пропусков non-null object) - требует работы с пропусками
# **Апартаменты (булев тип)**

# %% [markdown]
# Проверим столбец на наличие пропусков. Если они будут, то наверняка это жилье, не являющееся апартаментами. Поэтому просто заменим значения на ноль и изменим тип на bool. </div>

# %%
data['is_apartment'].value_counts()
# Out:
# False    2720
# True       49
# Name: is_apartment, dtype: int64

# %%
data['is_apartment'].dtype
# Out:
# dtype('O')

# %%
data.loc[data['is_apartment'] != True, 'is_apartment'] = False
data['is_apartment'] = data['is_apartment'].astype('bool')

# %%
data['is_apartment'].value_counts()
# Out:
# False    23601
# True        49
# Name: is_apartment, dtype: int64

# %%
data['is_apartment'].dtype
# Out:
# dtype('bool')

# %% [markdown]
# <div style="border:solid purple 2px; padding: 20px"> <b>Вывод 2.1.10:</b> Предобработка столбца не заняла много ресурсов, данные отныне корректны </div>

# %% [markdown]
# ####  studio (23699 non-null bool) - корректен
# **Квартира-студия (булев тип)**

# %% [markdown]
# </b> Проверим столбец </div>

# %%
data['studio'].value_counts()
# Out:
# False    23501
# True       149
# Name: studio, dtype: int64

# %%
data['studio'].dtype
# Out:
# dtype('bool')

# %% [markdown]
# </b> Квартира-студия - это квартира без кухни, сделаем проверку - таких строк должно быть 149. </div>

# %%
data.loc[data['studio']==True, ['total_area', 'kitchen_area']]
# Out:
#        total_area  kitchen_area
# 144         27.00           NaN
# 440         27.11           NaN
# 608         25.00           NaN
# 697         24.10           NaN
# 716         17.00           NaN
# ...           ...           ...
# 22819       30.00           NaN
# 22828       28.00           NaN
# 23161       26.00           NaN
# 23505       26.00           NaN
# 23588       26.00           NaN
#
# [149 rows x 2 columns]

# %%
display('Количество студий в датафрейме:')
data.loc[data['studio']==True]['kitchen_area'].isna().sum()
# Out:
# 'Количество студий в датафрейме:'
# 149

# %% [markdown]
# <div style="border:solid purple 2px; padding: 20px"><b>Вывод 2.1.11:</b> Столбец корректен, посчитали количество квартир без кухни - 149 </div>

# %% [markdown]
# ####  open_plan (23699 non-null bool) - корректен
# **Свободная планировка (булев тип)**

# %% [markdown]
# </b> Проверим.. </div>

# %%
data['open_plan'].value_counts()
# Out:
# False    23584
# True        66
# Name: open_plan, dtype: int64

# %%
data['open_plan'].dtype
# Out:
# dtype('bool')

# %% [markdown]
# <div style="border:solid purple 2px; padding: 20px"> <b>Вывод 2.1.12:</b> Столбец корректен! </div>

# %% [markdown]
# ####  kitchen_area (21421 - 9,6% пропусков non-null float64) - требует работы с пропусками
# **Площадь кухни в квадратных метрах (м2)**

# %% [markdown]
#  Проверку и обработку пропусков будем производить по аналогии с п.2.1.8 </div>

# %%
data['kitchen_area'].value_counts()
# Out:
# 6.00     1300
# 10.00    1261
# 8.00     1109
# 9.00     1101
# 7.00     1062
#          ...
# 13.73       1
# 14.74       1
# 53.10       1
# 13.41       1
# 16.74       1
# Name: kitchen_area, Length: 965, dtype: int64

# %%
data['kitchen_area'].describe()
# Out:
# count    21381.000000
# mean        10.526811
# std          5.744688
# min          1.300000
# 25%          7.000000
# 50%          9.100000
# 75%         12.000000
# max        107.000000
# Name: kitchen_area, dtype: float64

# %%
data['kitchen_area'].hist(figsize=(10,5), bins=50, range=(1, 110))
# Out:
# <AxesSubplot:>

# %%
data.loc[:,['total_area', 'living_area', 'kitchen_area']]
# Out:
#        total_area  living_area  kitchen_area
# 0          108.00    51.000000         25.00
# 1           40.40    18.600000         11.00
# 2           56.00    34.300000          8.30
# 3          159.00    90.319527           NaN
# 4          100.00    32.000000         41.00
# ...           ...          ...           ...
# 23645      133.81    73.300000         13.83
# 23646       59.00    38.000000          8.50
# 23647       56.70    29.700000           NaN
# 23648       76.75    43.597633         23.30
# 23649       32.30    12.300000          9.00
#
# [23650 rows x 3 columns]

# %%
display('Пропущенных значений по площади кухни с учетом квартир-студий:')
data['kitchen_area'].isna().sum()
# Out:
# 'Пропущенных значений по площади кухни с учетом квартир-студий:'
# 2269

# %% [markdown]
#  Посчитали количество пропущенных значений по площади кухни (2269). Заполним пропуски медианными значениями kitchen_area в зависимости от total_area, так как, чем больше общая площадь, тем больше площадь жилая, и тем больше доля площади кухни. Будем также учитывать в расчетах кухни, что это не должны быть студия </div>

# %%
display('Квартир без квартир-студий всего:')
len(data.loc[data['studio']==False])
# Out:
# 'Квартир без квартир-студий всего:'
# 23501

# %%
display('Кухонь без квартир-студий всего:')
data.loc[(data['kitchen_area'].isna() == False) & (data['studio']==False), 'kitchen_area'].count()
# Out:
# 'Кухонь без квартир-студий всего:'
# 21381

# %%
ratio_kitchen_area = data.loc[(data['kitchen_area'].isna() == False) & (data['studio']==False), 'kitchen_area'] / data.loc[(data['total_area'].isna() == False) & (data['studio']==False), 'total_area']
ratio_kitchen_area_median = ratio_kitchen_area.dropna().median()
ratio_kitchen_area_mean = ratio_kitchen_area.dropna().mean()

# %%
display('Медиана площади кухни:')
ratio_kitchen_area_median
# Out:
# 'Медиана площади кухни:'
# 0.1724137931034483

# %%
display('Среднее площади кухни:')
ratio_kitchen_area_mean
# Out:
# 'Среднее площади кухни:'
# 0.1874063744125858

# %% [markdown]
#  Поскольку медианное и среднее значения практически равны, выберем медиану и присвоим ее значение доле</div>

# %%
ratio_kitchen_area = ratio_kitchen_area_median

# %% [markdown]
#  Создадим список для индексов, где есть пропуски в значениях kitchen_area </div>

# %%
index_non_kitch = data.loc[(data['kitchen_area'].isna() == True) & (data['studio']==False)].index
data.loc[index_non_kitch, 'kitchen_area'] = ratio_kitchen_area * data.loc[index_non_kitch, 'total_area']

# %%
data.loc[(data['studio']==False),'kitchen_area'].isna().sum()
# Out:
# 0

# %% [markdown]
# Видим, что заполнение медианами не изменит ситуацию, слишком оно мало,  принудительно установим интервал площадей кухни в рамках разумного - от 3 до 50 м2. Не забываем, что студии мы исключаем </div>

# %%
data.loc[(data['kitchen_area']<3) & (data['studio']==False), 'kitchen_area'] = 3
data.loc[(data['kitchen_area']>50) & (data['studio']==False), 'kitchen_area'] = 50

# %%
data.loc[(data['studio']==False),'kitchen_area'].describe()
# Out:
# count    23501.000000
# mean        10.443759
# std          5.526557
# min          3.000000
# 25%          7.000000
# 50%          9.000000
# 75%         12.000000
# max         50.000000
# Name: kitchen_area, dtype: float64

# %%
data.loc[:,['total_area', 'living_area', 'kitchen_area']]
# Out:
#        total_area  living_area  kitchen_area
# 0          108.00    51.000000     25.000000
# 1           40.40    18.600000     11.000000
# 2           56.00    34.300000      8.300000
# 3          159.00    90.319527     27.413793
# 4          100.00    32.000000     41.000000
# ...           ...          ...           ...
# 23645      133.81    73.300000     13.830000
# 23646       59.00    38.000000      8.500000
# 23647       56.70    29.700000      9.775862
# 23648       76.75    43.597633     23.300000
# 23649       32.30    12.300000      9.000000
#
# [23650 rows x 3 columns]

# %% [markdown]
# <div style="border:solid purple 2px; padding: 20px"> <b>Вывод 2.1.13:</b> После предобработки столбец kitchen_area обрел правдоподобность. Но также помним, что в строках по квартирам студиям (149 позиций) будет стоять пропуск</div>

# %% [markdown]
# ####  balcony (12180 - 48,6% пропусков non-null float64) - требует работы с пропусками
# **Число балконов**

# %% [markdown]
#  Изучим пропуски в столбце </div>

# %%
data['balcony'].value_counts()
# Out:
# 1.0    4189
# 0.0    3747
# 2.0    3655
# 5.0     302
# 4.0     183
# 3.0      80
# Name: balcony, dtype: int64

# %%
data['balcony'].isna().sum()
# Out:
# 11494

# %% [markdown]
# Предположим, что в объявлениях не было указано наличие балкона. Логичнее предположить, что в квартире чаще всего находится 1 балкон (не учитываем районы Крайнего Севера, где балконы в большинстве квартир остсутствуют, Ленинградская область к ним не относится). Заменим пропуски на 1 и проверим результаты обработки </div>

# %%
data['balcony'] = data['balcony'].fillna(1)

# %%
data['balcony'].value_counts()
# Out:
# 1.0    15683
# 0.0     3747
# 2.0     3655
# 5.0      302
# 4.0      183
# 3.0       80
# Name: balcony, dtype: int64

# %%
data['balcony'].isna().sum()
# Out:
# 0

# %%
data['balcony'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# Заменим тип на int </div>

# %%
data['balcony'] = data['balcony'].astype(int)

# %%
data['balcony'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# <div style="border:solid purple 2px; padding: 20px"><b>Вывод 2.1.14:</b> Столбец обработан =)</div>

# %% [markdown]
# ####  locality_name (23650 - 49 пропусков non-null object) - требует работы с пропусками и доп.анализа
# **Название населенного пункта**

# %% [markdown]
# Изучим количественные данные, количество пропусков и уникальные значения </div>

# %%
data['locality_name'].value_counts()
# Out:
# Санкт-Петербург                          15675
# посёлок Мурино                             522
# посёлок Шушары                             440
# Всеволожск                                 398
# Пушкин                                     369
#                                          ...
# поселок городского типа Большая Ижора        1
# поселок Гаврилово                            1
# поселок Пчевжа                               1
# деревня Кисельня                             1
# деревня Малая Романовка                      1
# Name: locality_name, Length: 364, dtype: int64

# %% [markdown]
#  Санкт-Петербург занимает бОльшую часть всего рынка квартир </div>

# %%
data['locality_name'].isna().sum()
# Out:
# 49

# %% [markdown]
# Пропущенных значений всего 49 </div>

# %%
data['locality_name'].sort_values().unique()
# Out:
# array(['Бокситогорск', 'Волосово', 'Волхов', 'Всеволожск', 'Выборг',
#        'Высоцк', 'Гатчина', 'Зеленогорск', 'Ивангород', 'Каменногорск',
#        'Кингисепп', 'Кириши', 'Кировск', 'Колпино', 'Коммунар',
#        'Красное Село', 'Кронштадт', 'Кудрово', 'Лодейное Поле',
#        'Ломоносов', 'Луга', 'Любань', 'Мурино', 'Никольское',
#        'Новая Ладога', 'Отрадное', 'Павловск', 'Петергоф', 'Пикалёво',
#        'Подпорожье', 'Приморск', 'Приозерск', 'Пушкин', 'Санкт-Петербург',
#        'Светогорск', 'Сертолово', 'Сестрорецк', 'Сланцы', 'Сосновый Бор',
#        'Сясьстрой', 'Тихвин', 'Тосно', 'Шлиссельбург',
#        'городской поселок Большая Ижора', 'городской поселок Янино-1',
#        'городской посёлок Будогощь', 'городской посёлок Виллози',
#        'городской посёлок Лесогорский', 'городской посёлок Мга',
#        'городской посёлок Назия', 'городской посёлок Новоселье',
#        'городской посёлок Павлово', 'городской посёлок Рощино',
# ...

# %% [markdown]
#  Сразу бросаются в глаза следующие пары:
#
#  "посЕлок/посЁлок",
#
#  "посёлок городского типа/городской посёлок",
#
#  "поселок станции/поселок при железнодорожной станции",
#
#  "деревня Калитино"/"деревня Кальтино",
#
#  "деревня Курковицы"/"деревня Куровицы",
#
#  "посёлок Сапёрное"/"посёлок Сапёрный"

# %% [markdown]
#  Произведем замену буквы Ё на Е в обоих регистрах сразу по всему столбцу с названиями населенных пунктов. Для этого подключим модуль для регулярных выражений re и применим метод sub, который возвращает измененную строку. Пропишем цикл со счетчиком:</div>

# %%
counter = 0
for index_string in data.loc[(data['locality_name'].isna()==False),'locality_name'].index:    
    local_string = data.loc[index_string, 'locality_name']
    if ('ё' or 'Ё') in local_string:
        counter+=1
        local_string = re.sub('ё', 'е', local_string)
        local_string = re.sub('Ё', 'Е', local_string)
    data.loc[index_string, 'locality_name'] = local_string

# %%
data['locality_name'].sort_values().unique()
# Out:
# array(['Бокситогорск', 'Волосово', 'Волхов', 'Всеволожск', 'Выборг',
#        'Высоцк', 'Гатчина', 'Зеленогорск', 'Ивангород', 'Каменногорск',
#        'Кингисепп', 'Кириши', 'Кировск', 'Колпино', 'Коммунар',
#        'Красное Село', 'Кронштадт', 'Кудрово', 'Лодейное Поле',
#        'Ломоносов', 'Луга', 'Любань', 'Мурино', 'Никольское',
#        'Новая Ладога', 'Отрадное', 'Павловск', 'Петергоф', 'Пикалево',
#        'Подпорожье', 'Приморск', 'Приозерск', 'Пушкин', 'Санкт-Петербург',
#        'Светогорск', 'Сертолово', 'Сестрорецк', 'Сланцы', 'Сосновый Бор',
#        'Сясьстрой', 'Тихвин', 'Тосно', 'Шлиссельбург',
#        'городской поселок Большая Ижора', 'городской поселок Будогощь',
#        'городской поселок Виллози', 'городской поселок Лесогорский',
#        'городской поселок Мга', 'городской поселок Назия',
#        'городской поселок Новоселье', 'городской поселок Павлово',
#        'городской поселок Рощино', 'городской поселок Свирьстрой',
# ...

# %% [markdown]
# Буквы заменили, произведем аналогичную замену пары "поселок городского типа/городской поселок" ([как говорит Вики](https://ru.wikipedia.org/wiki/Населённые_пункты_Ленинградской_области) - это одно и то же). </div>

# %%
counter = 0
for index_string in data.loc[(data['locality_name'].isna()==False),'locality_name'].index:    
    local_string = data.loc[index_string, 'locality_name']
    if ('городской поселок') in local_string:
        counter+=1
        local_string = re.sub('городской поселок', 'поселок городского типа', local_string)
    data.loc[index_string, 'locality_name'] = local_string

# %%
data['locality_name'].sort_values().unique()
# Out:
# array(['Бокситогорск', 'Волосово', 'Волхов', 'Всеволожск', 'Выборг',
#        'Высоцк', 'Гатчина', 'Зеленогорск', 'Ивангород', 'Каменногорск',
#        'Кингисепп', 'Кириши', 'Кировск', 'Колпино', 'Коммунар',
#        'Красное Село', 'Кронштадт', 'Кудрово', 'Лодейное Поле',
#        'Ломоносов', 'Луга', 'Любань', 'Мурино', 'Никольское',
#        'Новая Ладога', 'Отрадное', 'Павловск', 'Петергоф', 'Пикалево',
#        'Подпорожье', 'Приморск', 'Приозерск', 'Пушкин', 'Санкт-Петербург',
#        'Светогорск', 'Сертолово', 'Сестрорецк', 'Сланцы', 'Сосновый Бор',
#        'Сясьстрой', 'Тихвин', 'Тосно', 'Шлиссельбург',
#        'деревня Агалатово', 'деревня Аро', 'деревня Батово',
#        'деревня Бегуницы', 'деревня Белогорка', 'деревня Большая Вруда',
#        'деревня Большая Пустомержа', 'деревня Большие Колпаны',
#        'деревня Большое Рейзино', 'деревня Большой Сабск', 'деревня Бор',
#        'деревня Борисова Грива', 'деревня Ваганово', 'деревня Вартемяги',
# ...

# %%
counter = 0
for index_string in data.loc[(data['locality_name'].isna()==False),'locality_name'].index:    
    local_string = data.loc[index_string, 'locality_name']
    if ('поселок при железнодорожной станции') in local_string:
        counter+=1
        local_string = re.sub('поселок при железнодорожной станции', 'поселок станции', local_string)
    data.loc[index_string, 'locality_name'] = local_string

# %%
data['locality_name'].sort_values().unique()
# Out:
# array(['Бокситогорск', 'Волосово', 'Волхов', 'Всеволожск', 'Выборг',
#        'Высоцк', 'Гатчина', 'Зеленогорск', 'Ивангород', 'Каменногорск',
#        'Кингисепп', 'Кириши', 'Кировск', 'Колпино', 'Коммунар',
#        'Красное Село', 'Кронштадт', 'Кудрово', 'Лодейное Поле',
#        'Ломоносов', 'Луга', 'Любань', 'Мурино', 'Никольское',
#        'Новая Ладога', 'Отрадное', 'Павловск', 'Петергоф', 'Пикалево',
#        'Подпорожье', 'Приморск', 'Приозерск', 'Пушкин', 'Санкт-Петербург',
#        'Светогорск', 'Сертолово', 'Сестрорецк', 'Сланцы', 'Сосновый Бор',
#        'Сясьстрой', 'Тихвин', 'Тосно', 'Шлиссельбург',
#        'деревня Агалатово', 'деревня Аро', 'деревня Батово',
#        'деревня Бегуницы', 'деревня Белогорка', 'деревня Большая Вруда',
#        'деревня Большая Пустомержа', 'деревня Большие Колпаны',
#        'деревня Большое Рейзино', 'деревня Большой Сабск', 'деревня Бор',
#        'деревня Борисова Грива', 'деревня Ваганово', 'деревня Вартемяги',
# ...

# %%
data['locality_name'].value_counts()
# Out:
# Санкт-Петербург            15675
# поселок Мурино               556
# поселок Шушары               440
# Всеволожск                   398
# Пушкин                       369
#                            ...
# поселок станции Лужайка        1
# деревня Лаврики                1
# поселок Красносельское         1
# деревня Лупполово              1
# поселок Белоостров             1
# Name: locality_name, Length: 321, dtype: int64

# %% [markdown]
# Замену пар "поселок городского типа/городской поселок" и "поселок при железнодорожной станции"/"поселок станции" произвели. С остальными парами попробуем разобраться, один ли это и тот же населенный пункт, исходя из значений столбца с расстоянием до ближайшего аэропорта airports_nearest и центра города cityCenters_nearest.</div>

# %%
data.query('locality_name=="деревня Калитино" or locality_name=="деревня Кальтино"')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 347               9     4400000        72.0           2018-08-31      2
# 1995             10     1555000        57.1           2017-01-09      3
# 2358             12     4150000        67.8           2018-09-13      2
# 4071             20     5999000        75.3           2019-02-25      2
# 4732             14     2995000        40.4           2018-10-22      1
# 4881             20     3850000        47.6           2016-08-27      1
# 5422              9     1499000        41.8           2018-09-28      2
# 7120              6     1100000        29.9           2018-02-18      1
# 8076              8      850000        28.0           2018-02-07      1
# 11288             9     6529500       131.9           2018-09-20      4
# 11433             7     1200000        59.0           2014-12-11      3
# 12337             7     1200000        46.0           2018-02-13      2
# ...

# %%
data.query('locality_name=="деревня Курковицы" or locality_name=="деревня Куровицы"')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 11984            10      950000        37.1           2019-05-03      1
# 17086             8     1150000        50.9           2017-08-25      2
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 11984             265             4         17.0      4         False  ...
# 17086             265             2         28.3      2         False  ...
#
#        kitchen_area  balcony      locality_name  airports_nearest  \
# 11984           8.4        2  деревня Курковицы               NaN
# 17086           8.5        1   деревня Куровицы               NaN
#
#       cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 11984                 NaN               NaN            NaN               NaN
# 17086                 NaN               NaN            NaN               NaN
#
#        ponds_nearest  days_exposition
# 11984            NaN              NaN
# ...

# %%
data.query('locality_name =="поселок Саперное" or locality_name =="поселок Саперный"')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 2961              7     3150000        49.7           2018-03-30      2
# 6534             13     2599000        41.7           2017-06-29      2
# 7459              5     3200000        42.0           2015-05-29      2
# 7629              1     1550000        47.0           2017-11-08      2
# 14108             6     1750000        59.7           2017-05-11      3
# 14477            12     2250000        33.0           2019-04-02      1
# 21201             7     2700000        38.5           2017-07-13      1
# 22679            15     3270000        51.7           2017-11-13      2
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 2961              258             5         27.8      5         False  ...
# 6534              272             3         27.7      3         False  ...
# 7459              265             3         29.7      2         False  ...
# ...

# %% [markdown]
#  Данная проверка нам не дала результата, столбец с ближайжим аэропортом заполнен почти во всех случаях пустыми значениями (за исключением поселка Саперный =~34 км. до аэропорта и 35 км до центра города). Обратимся [к Интернету](https://ru.wikipedia.org/wiki/Населённые_пункты_Ленинградской_области), чтобы понять, имели ли место опечатки в написании населенных пунктов.
#
#     "деревня Калитино"/"деревня Кальтино" - Волосовский/Всеволожский муниципальные районы, разные деревни, с разным населением. Сравним координаты (по данным 2ГИС): 59.41808° 29.641608°/59.983861° 30.665682°
#     "деревня Курковицы"/"деревня Куровицы" - Волосовский/Гатчинский муниципальные районы, разные деревни, с разным населением. Сравним координаты (по данным 2ГИС): 59.427519° 29.675211°/59.390718° 30.140008°
#     "поселок Саперное"/"поселок Саперный" - Приозерский/ Колпинский муниципальные районы, разные поселки, с разным населением. Сравним координаты (по данным 2ГИС): 60.712452° 29.961174°/59.779827° 30.682905°
#
# Очевидно, это разные населенные пункты, оставим их в покое.
#
# Перейдем к работе над пропусками, у нас их 49. Чтобы от них не избавляться и попробовать заменить на реальные населенные пункты, изучим все данные столбцов с расстояниями для наших пропусков</div>

# %%
distances = data.loc[data['locality_name'].isna()==True, ['cityCenters_nearest', 'airports_nearest', 'parks_nearest', 'ponds_nearest']]
distances
# Out:
#        cityCenters_nearest  airports_nearest  parks_nearest  ponds_nearest
# 1095                4258.0           23478.0            NaN            NaN
# 2027                   NaN               NaN            NaN            NaN
# 2595               17369.0           22041.0            NaN          374.0
# 2624               17369.0           22041.0            NaN          374.0
# 3564                8127.0           27419.0            NaN          603.0
# 4141                3902.0           25054.0          485.0          722.0
# 4179                3039.0           21774.0          690.0          953.0
# 4660                5382.0           26534.0          446.0          376.0
# 5332                9538.0           10556.0           67.0            NaN
# 5696               16788.0           21460.0            NaN          170.0
# 6751               17369.0           22041.0            NaN          374.0
# ...

# %% [markdown]
# </b> Меньше всего пропусков в столбцах cityCenters_nearest и airports_nearest, удалим эти пропущенные значения, а заполненные будем использовать в качестве "маячка" для поиска примерного местоположения и, соответственно, названия населенного пункта (ищем похожие названия).</div>

# %%
distances_full = distances.dropna(subset=['cityCenters_nearest', 'airports_nearest'])
distances_full
# Out:
#        cityCenters_nearest  airports_nearest  parks_nearest  ponds_nearest
# 1095                4258.0           23478.0            NaN            NaN
# 2595               17369.0           22041.0            NaN          374.0
# 2624               17369.0           22041.0            NaN          374.0
# 3564                8127.0           27419.0            NaN          603.0
# 4141                3902.0           25054.0          485.0          722.0
# 4179                3039.0           21774.0          690.0          953.0
# 4660                5382.0           26534.0          446.0          376.0
# 5332                9538.0           10556.0           67.0            NaN
# 5696               16788.0           21460.0            NaN          170.0
# 6751               17369.0           22041.0            NaN          374.0
# 7100                8582.0           14031.0            NaN            NaN
# ...

# %% [markdown]
# Пропишем цикл for/try/except, для этого создадим пустой список, в который будем собирать совпадающее по расстояниям значение населенного пункта, и пустой словарь, в котором ключом будет индекс пропущенного значения, а значением - значение из списка совпавших по расстояниям. В качестве "люфта" примем отклонение в расстояниях ~ 500 метров (думаю, это допустимая величина, чтобы "различить" населенный пункт) </div>

# %%
name_list = []
name_dict = dict()
div = 500
for index in distances_full.index:
    city = distances_full.loc[index, 'cityCenters_nearest']
    air = distances_full.loc[index, 'airports_nearest']
    try:
        name_list = data.query('((@city-@div)<cityCenters_nearest<(@city+@div)) and ((@air-@div)<airports_nearest<(@air+@div))')['locality_name']
    except:
        name_list = np.nan
    #display(name_list)
    name_dict[index] = set(name_list)

# %%
for i in distances_full.index:
    print(i, name_dict[i])
# Out:
# 1095 {nan, 'Санкт-Петербург'}
# 2595 {nan, 'Санкт-Петербург'}
# 2624 {nan, 'Санкт-Петербург'}
# 3564 {nan, 'Санкт-Петербург'}
# 4141 {nan, 'Санкт-Петербург'}
# 4179 {nan, 'Санкт-Петербург'}
# 4660 {nan, 'Санкт-Петербург'}
# 5332 {nan, 'Санкт-Петербург'}
# 5696 {nan, 'Санкт-Петербург'}
# 6751 {nan, 'Санкт-Петербург'}
# 7100 {nan, 'Санкт-Петербург'}
# 7316 {nan, 'Санкт-Петербург'}
# 7585 {nan, 'Санкт-Петербург'}
# 8551 {nan, 'Санкт-Петербург'}
# 8967 {nan, 'Павловск', 'Пушкин'}
# 9802 {nan, 'Санкт-Петербург'}
# 10103 {nan, 'Санкт-Петербург'}
# 11229 {nan, 'Санкт-Петербург'}
# 12858 {nan, 'Санкт-Петербург'}
# 12915 {nan, 'Санкт-Петербург'}
# 13201 {nan, 'Санкт-Петербург'}
# 13668 {nan, 'Санкт-Петербург'}
# 14249 {nan, 'Санкт-Петербург'}
# 15658 {nan, 'Санкт-Петербург'}
# 15837 {nan, 'Санкт-Петербург'}
# 16468 {nan, 'Санкт-Петербург'}
# 16530 {nan, 'Санкт-Петербург'}
# 16579 {nan, 'Санкт-Петербург'}
# 17730 {nan, 'Санкт-Петербург'}
# 18491 {nan, 'Санкт-Петербург'}
# ...

# %% [markdown]
# Строки (8967 и 21007), где совпало по 2 населенных пункта (Павловск и Пушкин) и где не совпало ничего (21234), удалим. Остальные значения заполним "Санкт-Петербургом". </div>

# %%
for i in distances_full.index:
    if 'Санкт-Петербург' in name_dict[i]:
        data.loc[i,'locality_name'] = 'Санкт-Петербург'
    print(i, data.loc[i,'locality_name'])
# Out:
# 1095 Санкт-Петербург
# 2595 Санкт-Петербург
# 2624 Санкт-Петербург
# 3564 Санкт-Петербург
# 4141 Санкт-Петербург
# 4179 Санкт-Петербург
# 4660 Санкт-Петербург
# 5332 Санкт-Петербург
# 5696 Санкт-Петербург
# 6751 Санкт-Петербург
# 7100 Санкт-Петербург
# 7316 Санкт-Петербург
# 7585 Санкт-Петербург
# 8551 Санкт-Петербург
# 8967 nan
# 9802 Санкт-Петербург
# 10103 Санкт-Петербург
# 11229 Санкт-Петербург
# 12858 Санкт-Петербург
# 12915 Санкт-Петербург
# 13201 Санкт-Петербург
# 13668 Санкт-Петербург
# 14249 Санкт-Петербург
# 15658 Санкт-Петербург
# 15837 Санкт-Петербург
# 16468 Санкт-Петербург
# 16530 Санкт-Петербург
# 16579 Санкт-Петербург
# 17730 Санкт-Петербург
# 18491 Санкт-Петербург
# 18882 Санкт-Петербург
# 19010 Санкт-Петербург
# 19933 Санкт-Петербург
# 20018 Санкт-Петербург
# 20613 Санкт-Петербург
# 21077 nan
# 21234 nan
# 21291 Санкт-Петербург
# 22428 Санкт-Петербург
# 22884 Санкт-Петербург
# 23165 Санкт-Петербург

# %% [markdown]
# Отлично, большинство пропусков заполнили, но они еще остались, проверим их количество и избавимся от них. Переиндексуем после этого нашу таблицу </div>

# %%
data['locality_name'].isna().sum()
# Out:
# 11

# %%
data.dropna(subset = ['locality_name'], inplace=True)
data['locality_name'].isna().sum()
# Out:
# 0

# %%
data.reset_index(inplace=True, drop=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23639 entries, 0 to 23638
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23639 non-null  int64
#  1   last_price            23639 non-null  int64
#  2   total_area            23639 non-null  float64
#  3   first_day_exposition  23639 non-null  datetime64[ns]
#  4   rooms                 23639 non-null  int64
#  5   ceiling_height        23639 non-null  int64
#  6   floors_total          23639 non-null  int64
#  7   living_area           23639 non-null  float64
#  8   floor                 23639 non-null  int64
#  9   is_apartment          23639 non-null  bool
#  10  studio                23639 non-null  bool
#  11  open_plan             23639 non-null  bool
#  12  kitchen_area          23490 non-null  float64
#  13  balcony               23639 non-null  int64
#  14  locality_name         23639 non-null  object
# ...

# %% [markdown]
# <div style="border:solid purple 2px; padding: 20px"><b>Вывод 2.1.15:</b> Удалено всего 11 строк, названия населенных пунктов переименованы и приведены к единообразию (красота) =) </div>

# %% [markdown]
# ####  airports_nearest (18157 - 23,4% пропусков non-null float64 - заменить) - требует работы с пропусками
# **Расстояние до ближайшего аэропорта в метрах**

# %% [markdown]
#  Изучим данные по столбцу </div>

# %%
data['airports_nearest'].value_counts()
# Out:
# 37434.0    61
# 21928.0    32
# 44870.0    30
# 39946.0    30
# 37407.0    27
#            ..
# 35904.0     1
# 48769.0     1
# 13720.0     1
# 44471.0     1
# 20875.0     1
# Name: airports_nearest, Length: 8259, dtype: int64

# %%
data['airports_nearest'].describe()
# Out:
# count    18108.000000
# mean     28798.655677
# std      12641.936867
# min          0.000000
# 25%      18573.000000
# 50%      26743.500000
# 75%      37310.000000
# max      84869.000000
# Name: airports_nearest, dtype: float64

# %% [markdown]
# Есть нули, посмотрим, сколько их </div>

# %%
data['airports_nearest'].isna().sum()
# Out:
# 5531

# %% [markdown]
# Заполним пропуски медианами значений столбца airports_nearest,  если не NaN,  из тех строк, в которых есть совпадение по названию населенного пункта. Для этого сгруппируем медианы аэропортов и "дропнем" </div>

# %%
air_median = data.groupby('locality_name')['airports_nearest'].median().sort_values()
air_median = air_median.dropna()
air_median.head()
# Out:
# locality_name
# поселок Александровская    12896.5
# Пушкин                     15766.0
# поселок Шушары             17427.0
# Павловск                   20529.5
# поселок Петро-Славянка     20605.0
# Name: airports_nearest, dtype: float64

# %% [markdown]
#  Напишем функцию замены пропуска медианой, применим ее и посчитаем оставшееся количество пропусков </div>

# %%
def insert_median(air_distance):
    if air_distance not in air_median:
        return np.nan
    return air_median[air_distance]
insert_median('Пушкин')
# Out:
# 15766.0

# %%
data.loc[data['airports_nearest'].isna()==True, 'airports_nearest'] = data['locality_name'].apply(insert_median)

# %%
data['airports_nearest'].isna().sum()
# Out:
# 4862

# %% [markdown]
# <div style="border:solid purple 2px; padding: 20px"><b>Вывод 2.1.16:</b> Пропуски остались, но на дальнейшее исследование они не повлияют, так что можно закрыть на них глаза (без удовольствия)</div>

# %% [markdown]
# ####  cityCenters_nearest (18180 - 23,3% пропусков non-null float64 - заменить) - требует приведения названия столбца к "змеиному регистру", а также работы с пропусками
# **Расстояние до центра города**

# %% [markdown]
#  Для начала заменим название столбца, а потом изучим его данные </div>

# %%
data.rename(columns={'cityCenters_nearest': 'city_centers_nearest'}, inplace=True)

# %%
data['city_centers_nearest'].value_counts()
# Out:
# 8460.0     61
# 20802.0    32
# 10720.0    30
# 8434.0     27
# 8370.0     26
#            ..
# 8565.0      1
# 5278.0      1
# 11575.0     1
# 3205.0      1
# 4234.0      1
# Name: city_centers_nearest, Length: 7626, dtype: int64

# %%
data['city_centers_nearest'].isna().sum()
# Out:
# 5508

# %%
data['city_centers_nearest'].describe()
# Out:
# count    18131.000000
# mean     14208.051238
# std       8602.498092
# min        181.000000
# 25%       9267.000000
# 50%      13114.000000
# 75%      16296.000000
# max      65968.000000
# Name: city_centers_nearest, dtype: float64

# %%
data.hist('city_centers_nearest', bins=100, figsize=(10,5))
# Out:
# array([[<AxesSubplot:title={'center':'city_centers_nearest'}>]],
#       dtype=object)

# %% [markdown]
# Данные распределены в общей массе нормально, кто-то живет прямо в центре, ну а кто-то и в 65-67 км от него. Займемся пропусками, у нас их 5508. Аналогично предыдущему пункту заполним медианой расстояний, также пропишем и применим функцию </div>

# %%
centr_median = data.groupby('locality_name')['city_centers_nearest'].median().sort_values()
centr_median = centr_median.dropna()
centr_median.head()
def insert_median(centr_distance):
    if centr_distance not in centr_median:
        return np.nan
    return centr_median[centr_distance]
insert_median('Пушкин')
data.loc[data['city_centers_nearest'].isna()==True, 'city_centers_nearest'] = data['locality_name'].apply(insert_median)
data['city_centers_nearest'].isna().sum()
# Out:
# 4862

# %% [markdown]
# </b> Было 5508, стало 4862, много. Изучим еще раз общие данные датафрейма  </div>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23639 entries, 0 to 23638
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23639 non-null  int64
#  1   last_price            23639 non-null  int64
#  2   total_area            23639 non-null  float64
#  3   first_day_exposition  23639 non-null  datetime64[ns]
#  4   rooms                 23639 non-null  int64
#  5   ceiling_height        23639 non-null  int64
#  6   floors_total          23639 non-null  int64
#  7   living_area           23639 non-null  float64
#  8   floor                 23639 non-null  int64
#  9   is_apartment          23639 non-null  bool
#  10  studio                23639 non-null  bool
#  11  open_plan             23639 non-null  bool
#  12  kitchen_area          23490 non-null  float64
#  13  balcony               23639 non-null  int64
#  14  locality_name         23639 non-null  object
# ...

# %% [markdown]
# Подозрительно выглядят 4 столбца С РАССТОЯНИЯМИ: airports_nearest, city_centers_nearest, parks_around3000, ponds_around3000 - приблизительно одинаковое количество пропусков, проверим их все вместе   </div>

# %%
unfilled_data = data.query('airports_nearest.isna()==True and city_centers_nearest.isna()==True and parks_around3000.isna()==True and ponds_around3000.isna()==True')
unfilled_data['locality_name'].count()
# Out:
# 4862

# %% [markdown]
# <div style="border:solid purple 2px; padding: 20px"><b>Вывод 2.1.17:</b> Вот как. Подозрения оправданы. Одновременно незаполненные столбцы с расстояниями тянут на баг-репорт =) Оставим его в датафрейме unfilled_data </div>

# %% [markdown]
# ####  parks_around3000 (18181 - 23,3% пропусков non-null float64 - заменить) - требует работы с пропусками
# **Число парков в радиусе 3 км**

# %% [markdown]
#  Посмотрим на данные и пропуски  </div>

# %%
data['parks_around3000'].value_counts()
# Out:
# 0.0    10089
# 1.0     5671
# 2.0     1735
# 3.0      637
# Name: parks_around3000, dtype: int64

# %%
data['parks_around3000'].isna().sum()
# Out:
# 5507

# %% [markdown]
# Возьмем на себя смелость (т.к. столбец для дальнейших исследований бесполезен) и предположим, что раз подавляющее большинство живет дальше, чем 3 км от парка, то пропуски также заменим на 0. А потом поменяем тип данных на int  </div>

# %%
data['parks_around3000'] = data['parks_around3000'].fillna(0)
data['parks_around3000'].value_counts()
# Out:
# 0.0    15596
# 1.0     5671
# 2.0     1735
# 3.0      637
# Name: parks_around3000, dtype: int64

# %%
data['parks_around3000'] = data['parks_around3000'].astype(int)
data['parks_around3000'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# <div style="border:solid purple 2px; padding: 20px"><b>Вывод 2.1.18:</b> С парками разобрались, столбец корректен </div>

# %% [markdown]
# ####  parks_nearest (8079 - 65,9% пропусков non-null float64 - заменить) - требует работы с пропусками
# **Расстояние до ближайшего парка (м)**

# %% [markdown]
# </b> Изучаем </div>

# %%
data['parks_nearest'].value_counts()
# Out:
# 441.0     67
# 392.0     41
# 173.0     41
# 456.0     40
# 471.0     32
#           ..
# 727.0      1
# 973.0      1
# 2348.0     1
# 794.0      1
# 929.0      1
# Name: parks_nearest, Length: 995, dtype: int64

# %%
data['parks_nearest'].isna().sum()
# Out:
# 15592

# %%
data['parks_nearest'].describe()
# Out:
# count    8047.000000
# mean      491.089350
# std       342.733209
# min         1.000000
# 25%       288.000000
# 50%       455.000000
# 75%       612.000000
# max      3190.000000
# Name: parks_nearest, dtype: float64

# %%
data.hist('parks_nearest', bins=100, figsize=(10,5))
# Out:
# array([[<AxesSubplot:title={'center':'parks_nearest'}>]], dtype=object)

# %% [markdown]
# Данные распределены равномерно, выбросов нет, ничего не удаляем. Заполним пропуски. Аналогично предыдущим пунктам заполним медианой расстояний, также пропишем и применим функцию </div>

# %%
park_median = data.groupby('locality_name')['parks_nearest'].median().sort_values()
park_median = park_median.dropna()
park_median.head()
def insert_median(park_distance):
    if park_distance not in park_median:
        return np.nan
    return park_median[park_distance]
insert_median('Пушкин')
# Out:
# 399.5

# %%
data.loc[data['parks_nearest'].isna()==True, 'parks_nearest'] = data['locality_name'].apply(insert_median)
data['parks_nearest'].isna().sum()
# Out:
# 5996

# %% [markdown]
#  <div style="border:solid purple 2px; padding: 20px"><b>Вывод 2.1.19:</b> Выводы аналогичны по предыдущим столбцам с расстояниями </div>

# %% [markdown]
# ####  ponds_around3000 (18181 - 23,3% пропусков non-null float64 - заменить) - требует работы с пропусками
# **Число водоемов в радиусе 3 км**

# %% [markdown]
#  По аналогии с числом парков в радиусе 3 км: </div>

# %%
data['ponds_around3000'].value_counts()
# Out:
# 0.0    9061
# 1.0    5707
# 2.0    1881
# 3.0    1483
# Name: ponds_around3000, dtype: int64

# %%
data['ponds_around3000'].isna().sum()
# Out:
# 5507

# %%
data['ponds_around3000'] = data['ponds_around3000'].fillna(0)
data['ponds_around3000'].value_counts()
# Out:
# 0.0    14568
# 1.0     5707
# 2.0     1881
# 3.0     1483
# Name: ponds_around3000, dtype: int64

# %%
data['ponds_around3000'] = data['ponds_around3000'].astype(int)
data['ponds_around3000'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# <div style="border:solid purple 2px; padding: 20px"> <b>Вывод 2.1.20:</b> Выводы аналогичны, столбец корректен </div>

# %% [markdown]
# ####  ponds_nearest (9110 - 65,5% пропусков non-null float64 - заменить) - требует работы с пропусками
# **Расстояние до ближайшего водоема в метрах**

# %% [markdown]
# По аналогии с расстояниями парков: </div>

# %%
data['ponds_nearest'].value_counts()
# Out:
# 427.0     70
# 454.0     41
# 153.0     40
# 433.0     39
# 474.0     37
#           ..
# 1020.0     1
# 985.0      1
# 193.0      1
# 23.0       1
# 995.0      1
# Name: ponds_nearest, Length: 1095, dtype: int64

# %%
data['ponds_nearest'].isna().sum()
# Out:
# 14568

# %%
data['ponds_nearest'].describe()
# Out:
# count    9071.000000
# mean      518.777092
# std       277.787029
# min        13.000000
# 25%       295.000000
# 50%       503.000000
# 75%       731.000000
# max      1344.000000
# Name: ponds_nearest, dtype: float64

# %%
data.hist('ponds_nearest', bins=100, figsize=(10,5))
# Out:
# array([[<AxesSubplot:title={'center':'ponds_nearest'}>]], dtype=object)

# %%
pond_median = data.groupby('locality_name')['ponds_nearest'].median().sort_values()
pond_median = pond_median.dropna()
pond_median.head()
def insert_median(pond_distance):
    if pond_distance not in pond_median:
        return np.nan
    return pond_median[pond_distance]
insert_median('Пушкин')
# Out:
# 444.0

# %%
data.loc[data['ponds_nearest'].isna()==True, 'ponds_nearest'] = data['locality_name'].apply(insert_median)
data['ponds_nearest'].isna().sum()
# Out:
# 4970

# %% [markdown]
#  <div style="border:solid purple 2px; padding: 20px"><b>Вывод 2.1.21:</b> Пропуски заполнили также. Столбец далее в исследовании не пригодится</div>

# %% [markdown]
# ####  days_exposition (20518 - 13,4% пропусков non-null float64 - заменить) - требует работы с пропусками
# **Сколько дней было размещено объявление (от публикации до снятия)**

# %% [markdown]
#  Изучим данные столбца </div>

# %%
data['days_exposition'].value_counts()
# Out:
# 45.0      879
# 60.0      538
# 7.0       234
# 30.0      208
# 90.0      203
#          ...
# 969.0       1
# 1147.0      1
# 1148.0      1
# 1345.0      1
# 1174.0      1
# Name: days_exposition, Length: 1140, dtype: int64

# %%
data['days_exposition'].describe()
# Out:
# count    20464.000000
# mean       180.695954
# std        219.623561
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        231.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %%
data.hist('days_exposition', bins=100, figsize=(10,5))
# Out:
# array([[<AxesSubplot:title={'center':'days_exposition'}>]], dtype=object)

# %%
data['days_exposition'].hist(bins=50, range=(1000,1600), figsize=(16,3));

# %%
data['days_exposition'].isna().sum()
# Out:
# 3175

# %% [markdown]
# Данные распределены закономерно, ничего не удаляем. Разберемся лучше с пропусками, у нас их 3175. Пропуски в данном столбце заполним нолями, не уходя в "медианные дебри", и сразу заменим тип.   </div>

# %%
data['days_exposition'] = data['days_exposition'].fillna(0).astype('int')

# %%
data['days_exposition'].describe()
# Out:
# count    23639.000000
# mean       156.426329
# std        213.429925
# min          0.000000
# 25%         22.000000
# 50%         73.000000
# 75%        198.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %%
data['days_exposition'].isna().sum()
# Out:
# 0

# %% [markdown]
# <div style="border:solid purple 2px; padding: 20px"> Очевидно, что объявления были загружены в разные дни. Пропуск могу объяснить тем, что на момент выгрузки нашей базы, эти объявления еще не утратили свою актуальность. Исходя из того, что эти квартиры еще продаются, то не совсем (или совсем не) корректно заполнять пропуски нулями, словно объекты были проданы в день размещения. Но сделаем вид, что это такая заглушка для пропусков и оставим в покое этот пункт :)
#
#
# Просто будем в голове держать, что такая заглушка может "выстрелить" на гистограмме пиком в самом неожиданном заглушечном месте</div>. </div>

# %%
test_data = data.query('days_exposition == 0')
test_data
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20    13000000      108.00           2019-03-07      3
# 7                 5     7915000       71.60           2019-04-18      2
# 44               13     5350000       40.00           2018-11-18      1
# 45               17     5200000       50.60           2018-12-02      2
# 46               17     6600000       52.10           2019-01-31      2
# ...             ...         ...         ...                  ...    ...
# 23621            20    21400000      145.00           2018-11-02      4
# 23622            15     2490000       31.00           2019-01-24      1
# 23631             9     9700000      133.81           2017-03-21      3
# 23633            18     2500000       56.70           2018-02-11      2
# 23635             4     1350000       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %% [markdown]
# ###  Обработка дубликатов

# %% [markdown]
# Возьмем первые 4 обработанных нами столбца для того, чтобы вычленить и удалить явные дубликаты. Совпадения по этим столбцам маловероятны и данные в них полны. </div>

# %%
data.duplicated(['total_images', 'last_price','first_day_exposition','total_area']).sum()
# Out:
# 4

# %%
duplicated_data = data[data[['total_images', 'last_price','first_day_exposition','total_area']].duplicated(keep=False)]
duplicated_data
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 9640              1     2533531       42.50           2016-09-08      1
# 10078            10     4400000       44.00           2017-11-22      1
# 14711            10     5142565       54.65           2018-10-01      2
# 18386             1     2533531       42.50           2016-09-08      1
# 18585            10     5142565       54.65           2018-10-01      2
# 19013             3     4370000       38.00           2016-06-23      1
# 19285             3     4370000       38.00           2016-06-23      1
# 21093            10     4400000       44.00           2017-11-22      2
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 9640              256            18    19.800000      7         False  ...
# 10078             265            17    17.000000     14         False  ...
# 14711             265             5    26.000000      3         False  ...
# ...

# %% [markdown]
# <div style="border:solid purple 2px; padding: 20px">
#
#
# Здесь:
#
# - строки 19013 и 19285 немного различаются этажом и жилой площадью, этаж может быть первым, но находится на высоте второго, поэтому указали, как 2 (строку 19013 удалим)
#
# - строки 9640 и 18386 различаются только этажом, также удаляем строку 9640
#
# - строки 10078 и 21093 имеют достаточно различий, очевидно, это разные квартиры, оставляем обе строки
#
# - строки 14711 и 18585 явно одна и та же квартира, удаляем строку 14711</div>

# %%
data.drop([19013,9640,14711], axis=0, inplace=True)
data.reset_index(drop=True, inplace=True)
display(data)
data.info()
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20    13000000      108.00           2019-03-07      3
# 1                 7     3350000       40.40           2018-12-04      1
# 2                10     5196000       56.00           2015-08-20      2
# 3                 0    64900000      159.00           2015-07-24      3
# 4                 2    10000000      100.00           2018-06-19      2
# ...             ...         ...         ...                  ...    ...
# 23631             9     9700000      133.81           2017-03-21      3
# 23632            14     3100000       59.00           2018-01-15      3
# 23633            18     2500000       56.70           2018-02-11      2
# 23634            13    11475000       76.75           2017-03-28      2
# 23635             4     1350000       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %% [markdown]
# <div style="border:solid purple 3px; padding: 20px">
#
# ###  Предобработка данных. Выводы
#
# Всего было **обработано** 22 столбца и **23699** строк. В результате работы **осталось корректных данных**, необходимых для исследования - **23636** строки, **потери** данных составили **0,27%**

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %% [markdown]
# ### Цена квадратного метра

# %% [markdown]
# </b> Цена_м2 = Стоимость/Общ_площадь. </div>

# %%
data['sq_metr_price'] = data['last_price'] / data['total_area']

# %%
data['sq_metr_price'] = data['sq_metr_price'].astype(int)
data['sq_metr_price'].dtype
# Out:
# dtype('int64')

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            10     5196000        56.0           2015-08-20      2
# 3             0    64900000       159.0           2015-07-24      3
# 4             2    10000000       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0             270            16    51.000000      8         False  ...
# 1             265            11    18.600000      1         False  ...
# 2             265             5    34.300000      4         False  ...
# 3             265            14    90.319527      9         False  ...
# 4             303            14    32.000000     13         False  ...
#
#    balcony    locality_name  airports_nearest  city_centers_nearest  \
# ...

# %% [markdown]
# ### День недели, месяц и год публикации объявления

# %%
data['day_exp'] = data['first_day_exposition'].dt.weekday
data['month_exp'] = data['first_day_exposition'].dt.month
data['year_exp'] = data['first_day_exposition'].dt.year

# %%
data[['day_exp', 'month_exp', 'year_exp']].head()
# Out:
#    day_exp  month_exp  year_exp
# 0        3          3      2019
# 1        1         12      2018
# 2        3          8      2015
# 3        4          7      2015
# 4        1          6      2018

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            10     5196000        56.0           2015-08-20      2
# 3             0    64900000       159.0           2015-07-24      3
# 4             2    10000000       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0             270            16    51.000000      8         False  ...
# 1             265            11    18.600000      1         False  ...
# 2             265             5    34.300000      4         False  ...
# 3             265            14    90.319527      9         False  ...
# 4             303            14    32.000000     13         False  ...
#
#    city_centers_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# ...

# %% [markdown]
# ### Этаж квартиры; варианты — первый, последний, другой;

# %% [markdown]
# Напишем функцию для нового сразу заготовленного пустого столбца с категориями этажа, внесем туда данные </div>

# %%
data['floor_category'] = np.nan
def floor_cat_insert(row):
    if row['floor']==1:
        return 'первый'
    elif row['floor']==row['floors_total']:
        return 'последний'
    else:
        return 'другой'
data['floor_category'] = data.apply(floor_cat_insert, axis=1)

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            10     5196000        56.0           2015-08-20      2
# 3             0    64900000       159.0           2015-07-24      3
# 4             2    10000000       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0             270            16    51.000000      8         False  ...
# 1             265            11    18.600000      1         False  ...
# 2             265             5    34.300000      4         False  ...
# 3             265            14    90.319527      9         False  ...
# 4             303            14    32.000000     13         False  ...
#
#    parks_around3000  parks_nearest  ponds_around3000  ponds_nearest  \
# ...

# %% [markdown]
# ### Cоотношение жилой и общей площади, а также отношение площади кухни к общей.

# %%
data['living_to_total'] = round(data['living_area'] / data['total_area'],2)

# %%
data['kitchen_to_total'] = round(data['kitchen_area'] / data['total_area'],2)

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            10     5196000        56.0           2015-08-20      2
# 3             0    64900000       159.0           2015-07-24      3
# 4             2    10000000       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0             270            16    51.000000      8         False  ...
# 1             265            11    18.600000      1         False  ...
# 2             265             5    34.300000      4         False  ...
# 3             265            14    90.319527      9         False  ...
# 4             303            14    32.000000     13         False  ...
#
#    ponds_around3000  ponds_nearest  days_exposition  sq_metr_price day_exp  \
# ...

# %% [markdown]
# <div style="border:solid purple 2px; padding: 20px">
#
# ### Выводы по расчетам и добавлению новых столбцов
# Необходимые расчеты произведены, добавлено **7 новых столбцов**

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Изучение параметров: площадь, цена, число комнат, высота потолков. Построение гистограммы для каждого параметра.

# %% [markdown]
# #### Площадь

# %%
data['total_area'].head(8)
# Out:
# 0    108.0
# 1     40.4
# 2     56.0
# 3    159.0
# 4    100.0
# 5     30.4
# 6     37.3
# 7     71.6
# Name: total_area, dtype: float64

# %%
data['total_area'].describe()
# Out:
# count    23636.000000
# mean        59.911860
# std         33.412687
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.600000
# max        590.000000
# Name: total_area, dtype: float64

# %%
data.boxplot(column='total_area', figsize=(3,7))
# Out:
# <AxesSubplot:>

# %%
data['total_area'].hist(figsize=(16,3), bins=100)
# Out:
# <AxesSubplot:>

# %%
data['total_area'].hist(range=(0,120),figsize=(10,5), bins=100)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <div style="border:solid purple 2px; padding: 20px"> <b>Выводы 4.1.1:</b> Ранжируем по популярности:
#
# - 1- и 2-комнатные квартиры с площадями от 31 до 46 м2 являются наиболее популярными на рынке жилья
#
# - затем квартиры с общей полщадью до 76 м2 (скорее всего двух-или трехкомнатные)
#
# - популярность квартир с большими площадями прямо убывает, что логично
#
# - микро-квартиры до 26-30 м2 замыкают наш рейтинг </div>

# %% [markdown]
# #### Цена

# %%
data['last_price'].head(8)
# Out:
# 0    13000000
# 1     3350000
# 2     5196000
# 3    64900000
# 4    10000000
# 5     2890000
# 6     3700000
# 7     7915000
# Name: last_price, dtype: int64

# %%
data['last_price'].describe()
# Out:
# count    2.363600e+04
# mean     6.249961e+06
# std      6.412914e+06
# min      4.300000e+05
# 25%      3.400000e+06
# 50%      4.630000e+06
# 75%      6.751265e+06
# max      9.900000e+07
# Name: last_price, dtype: float64

# %%
data.boxplot(column='last_price', figsize=(3,7))
# Out:
# <AxesSubplot:>

# %%
data['last_price'].hist(figsize=(16,3), bins=100)
# Out:
# <AxesSubplot:>

# %%
data['last_price'].hist(range=(0,15000000),figsize=(10,5), bins=80)
# Out:
# <AxesSubplot:>

# %% [markdown]
#  <div style="border:solid purple 2px; padding: 20px"><b>Выводы 4.1.2:</b>
#
# - квартиры стоимостью от 3,9 млн до 4,4 млн самые распространенные
#
# - квартиры в общей массе стоимостью от 1,8-1,9 млн и до 7,2 млн являются наиболее востребованными на рынке жилья
#
# - для диапазона от 7,2 млн: чем выше стоимость и больше площадь жилья пропорционально ниже интерес
#
# - для диапазона до 2 млн: чем выше стоимость и больше площадь жилья пропорционально выше интерес
#
#     Распределение похоже на распределение Пуассона
#
#  </div>

# %% [markdown]
# #### Число комнат

# %%
data['rooms'].head(8)
# Out:
# 0    3
# 1    1
# 2    2
# 3    3
# 4    2
# 5    1
# 6    1
# 7    2
# Name: rooms, dtype: int64

# %%
data['rooms'].describe()
# Out:
# count    23636.000000
# mean         2.074886
# std          1.057466
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         19.000000
# Name: rooms, dtype: float64

# %%
data.boxplot(column='rooms', figsize=(3,7))
# Out:
# <AxesSubplot:>

# %%
data['rooms'].hist(range=(0,10),figsize=(10,5), bins=10)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <div style="border:solid purple 2px; padding: 20px"> <b>Выводы 4.1.3:</b> Замечаем сразу - чем больше комнат, тем меньше квартир:
#
# - однокомнатные являются наиболее популярными на рынке жилья (более 8000 предложений)
#
# - чуть менее популярны двухкомнатные (чуть менее 8000)
#
# - трехкомнатные занимают почетное третье место (~ 5800)
#
# - и четырехкомнатных тоже хватит на всех желающих (их ~ 1200). Далее количество заметно снижается с ростом числа комнат
#
# Распределение похоже на распределение Пуассона</div>

# %% [markdown]
# #### Высота потолков

# %%
data['ceiling_height'].head(8)
# Out:
# 0    270
# 1    265
# 2    265
# 3    265
# 4    303
# 5    265
# 6    265
# 7    265
# Name: ceiling_height, dtype: int64

# %%
data['ceiling_height'].describe()
# Out:
# count    23636.000000
# mean       269.535454
# std         21.779118
# min        200.000000
# 25%        260.000000
# 50%        265.000000
# 75%        270.000000
# max        580.000000
# Name: ceiling_height, dtype: float64

# %%
data.boxplot(column='ceiling_height', figsize=(3,7))
# Out:
# <AxesSubplot:>

# %%
data['ceiling_height'].hist(range=(200,600),figsize=(10,5), bins=10)
# Out:
# <AxesSubplot:>

# %% [markdown]
#  <div style="border:solid purple 2px; padding: 20px"><b>Выводы 4.1.4:</b> Ранжируем по популярности:
#
# - больше всего квартир с высотой потолка от 240 до 280 см, на них приходится ~ 19500 предложений
#
# - затем квартиры с высотой 280-360 см (~3000)
#
# - далее чем выше потолок, тем меньше квартир
#
#     Распределение похоже на распределение Пуассона
# </div>

# %% [markdown]
# ### Изучение времени продажи квартиры
# Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?

# %%
data['days_exposition'].head(8)
# Out:
# 0      0
# 1     81
# 2    558
# 3    424
# 4    121
# 5     55
# 6    155
# 7      0
# Name: days_exposition, dtype: int64

# %%
data[data['days_exposition']!=0]['days_exposition'].describe()
# Out:
# count    20461.000000
# mean       180.654416
# std        219.595877
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        231.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %%
plt.boxplot(data[data['days_exposition']!=0]['days_exposition'])
data.plot(y = 'days_exposition', kind = 'hist', bins = 30, grid = True, range = (1,1600))
data.plot(y = 'days_exposition', kind = 'hist', bins = 100, grid = True, range = (1,200))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
display('Медиана времени продажи квартиры, дни:', data[data['days_exposition']!=0]['days_exposition'].median())
display('Средняя времени продажи квартиры, дни:', data[data['days_exposition']!=0]['days_exposition'].mean())
# Out:
# 'Медиана времени продажи квартиры, дни:'
# 95.0
# 'Средняя времени продажи квартиры, дни:'
# 180.65441571770685

# %% [markdown]
# <div style="border:solid purple 2px; padding: 20px"> <b>Выводы 4.2:</b>  Распределение ожидаемо похоже на распределение Пуассона, медиана 95, среднее ~180 дней, межквартильный размах - от 45 до 231 дней, исходя же из метода boxplot - диаграмма размаха у нас от минимального значения до ~ 500 дней - необоснованно быстрых продаж у нас нет, а необоснованно долгие - от 500 дней и выше. Можно считать нормальным продажу квартиры до ~ 1.37 года.
#
#
#
#    Здесь кое-что интересненькое наметилось =) При укрупнении диаграммы обнаружились резко выбивающиеся значения. Проверив их .value_counts(), убедились, что имеем аномальные значения - 45, 60, 7, 30, 90 (и подозрительно ровные).
#
#    Яндекс.Справка [подсказала](https://yandex.ru/support/realty/owner/home/add-ads-housing.html), что эти сроки - границы того, что объявление утрачивает актуальность и снимается за ненадобностью автоматически.
#
#    Поэтому, рассмотрим вариант дропнуть строки с этими значениями, но проверим, вдруг какие-то квартиры действительно попали в этот срок до снятия. Оставим это для следующего пункта. Однако, остается "подозрение", что медиана (95) останется прежней, уж больно она аномальна сама по себе =) Посмотрим, что получится.
#
#    Возможно, намечается второй предентент на баг-репорт, а, возможно, и нет =)
#
#
# </div>

# %% [markdown]
# ### Чистка редких и выбивающихся значений.
# Опишите, какие особенности обнаружили.

# %% [markdown]
#  Изучим аномалии из предыдущего пункта повнимательнее </div>

# %%
anomalous_data_45 = data[data['days_exposition']==45]
anomalous_data_45
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 78                9     4350000        37.0           2018-02-22      1
# 89                9     2500000        63.0           2018-10-25      3
# 110               6     3850000        72.3           2017-09-29      2
# 153              12     4350000        55.0           2017-05-21      2
# 158              15     3100000        47.3           2017-11-07      2
# ...             ...         ...         ...                  ...    ...
# 23538            10     2900000        43.4           2018-01-11      2
# 23550             4     3950000        52.0           2018-03-04      3
# 23607             9     2450000        45.6           2018-02-08      1
# 23616             0     2500000        35.0           2017-12-08      1
# 23632            14     3100000        59.0           2018-01-15      3
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %%
anomalous_data_60 = data[data['days_exposition']==60]
anomalous_data_60
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 22               20     5000000        58.0           2017-04-24      2
# 82                3     4500000        80.5           2018-01-15      3
# 105              12     4900000        32.0           2018-01-07      1
# 118               8     4500000        31.0           2019-02-24      1
# 143               9     2990000        30.0           2016-06-08      1
# ...             ...         ...         ...                  ...    ...
# 23514            10     3750000        45.0           2016-06-14      2
# 23537             8     8700000       132.0           2018-11-13      3
# 23558            11     5000000        37.9           2017-08-31      1
# 23572             9     5100000        36.0           2018-10-26      1
# 23579            14     5950000        80.3           2018-07-03      3
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %%
anomalous_data_7 = data[data['days_exposition']==7]
anomalous_data_7
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 11                9     3300000       44.00           2018-08-27      2
# 156              11    10990000       80.00           2018-06-25      2
# 301               7     3700000       47.00           2018-09-12      2
# 332               1     3300000       32.90           2018-11-01      1
# 337              19     5500000       55.00           2018-03-06      2
# ...             ...         ...         ...                  ...    ...
# 23181            15     3750000       37.90           2018-11-07      1
# 23207             9     6650000       56.80           2018-10-13      2
# 23344             0     3550000       67.60           2019-01-03      3
# 23418             1     3000000       37.29           2019-04-15      1
# 23450            12     8300000       62.60           2017-02-15      2
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %%
anomalous_data_30 = data[data['days_exposition']==30]
anomalous_data_30
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 157              15     7250000       75.75           2017-02-15      2
# 735              11     4500000       45.00           2018-01-16      2
# 799              15     5599000       55.50           2017-04-10      2
# 942              14     5500000       66.00           2018-11-19      2
# 969               9     3700000       37.40           2019-03-30      1
# ...             ...         ...         ...                  ...    ...
# 23266             3     3600000       67.90           2018-02-13      3
# 23332             4    40000000      188.00           2017-05-29      6
# 23338             5     3400000       32.00           2017-09-15      2
# 23400            10     3800000       40.70           2017-07-21      1
# 23463            14     5800000       60.69           2018-03-13      3
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %%
anomalous_data_90 = data[(data['days_exposition']==90)]
anomalous_data_90
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 12               10     3890000        54.0           2016-06-30      2
# 277               5     4600000        65.0           2017-10-12      3
# 424              14    11500000        98.0           2016-05-10      3
# 444               5     4200000        47.5           2018-08-17      2
# 447              13    12084000        86.6           2018-07-05      3
# ...             ...         ...         ...                  ...    ...
# 22337             9    14000000        68.0           2018-02-18      2
# 22369            16     4600000        44.0           2017-07-27      2
# 22867            13    14145000        85.0           2018-03-04      3
# 22997            13    20990000       100.0           2018-09-12      3
# 23568            17    14799000       104.0           2018-11-18      3
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %% [markdown]
# В обьявлениях, снятых через 45, 60, 7, 30 и 90 дней, общих особенностей не замечено, но убирать их совсем тоже не хочется. Сделаем проверку, отфильтруем аномалии, но перезапишем их в другой датафрейм, не трогая основной. Посмотрим, что получится.
#
#    НО сохраним для баг-репорта датафреймы (anomalous_data_45, anomalous_data_60, anomalous_data_7, anomalous_data_30 и anomalous_data_90) соответственно разделеные для упрощения дальнейшей работы коллег с ними и быстрого поиска бага.
#
#    Проблема в днях снятия может крыться в разных ошибках - к примеру, объявление могло быть помечено не на продажу, а на аренду - его срок снятия зависит от вида объекта и длительности аренды (здесь либо 7, либо 30 дней).  </div>

# %%
anom_test_data = data.query('days_exposition != 45 and days_exposition != 30 and days_exposition != 60 and days_exposition != 90 and days_exposition != 7 and days_exposition != 0')

# %%
anom_test_data.boxplot(column='days_exposition', figsize=(3,7))
# Out:
# <AxesSubplot:>

# %%
anom_test_data['days_exposition'].describe()
# Out:
# count    18399.000000
# mean       195.575140
# std        226.646486
# min          1.000000
# 25%         44.000000
# 50%        114.000000
# 75%        258.500000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %%
data[data['days_exposition']!=0]['days_exposition'].describe()
# Out:
# count    20461.000000
# mean       180.654416
# std        219.595877
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        231.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %%
#data['days_exposition'].describe()

# %% [markdown]
#  <div style="border:solid purple 2px; padding: 20px"><b>Выводы 4.3:</b>  В очищенных данных и данных с аномалиями:
#
# - медиана сместилась вправо с 95 до 114
#
# - среднее значение со 180 дней выросло до ~196
#
# - межквартильный размах - от 45 до 231 дней изменился на от 44 до 258 дней
#
# - нормальные значения отныне располагаются от 1 до до ~ 500 дней вместо от 1 до ~ 580 дней.
#
#     Совсем бы сейчас я убирать эти аномалии не стала, спросила бы у коллег, собирающих данные, где здесь собака зарыта может быть.
#
#     Все остальное было обнаружено и удалено на этапе 2. Предобработка данных

# %% [markdown]
# ### Какие факторы больше всего влияют на стоимость квартиры
# Изучите, зависит ли цена от площади, числа комнат, удалённости от центра. Изучите зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом. Также изучите зависимость от даты размещения: дня недели, месяца и года.

# %% [markdown]
# #### Зависимость цены от площади квартиры

# %% [markdown]
# Поскольку в данном пункте зависимость будем искать по одному алгоритму, для удобства пропишем функцию, которую и будем применять к разным величинам

# %%
def correlation(column):
    display('Коэффициент корреляции цены и',column, data['last_price'].corr(data[column]))
    data.plot(x=column, y='last_price', kind='scatter', grid=True, figsize=(10,5), alpha=0.5)

# %% [markdown]
# <div class="alert alert-success">
# <b>🤌 Комментарий ревьюера </b>
#
# Суперсуперсуперсуперсуперсупер</div>

# %%
correlation('total_area')
# Out:
# 'Коэффициент корреляции цены и'
# 'total_area'
# 0.768493668157224

# %% [markdown]
# <div style="border:solid purple 2px; padding: 20px"> <b>Выводы 4.4.1:</b> Коэффициент корреляции ~0.77, зависимость прямая, не такая сильная (при больших площадях особенно). Но очевидно, что при увеличении площади жилья, цена также растет

# %% [markdown]
# #### Зависимость цены от числа комнат в квартире

# %%
correlation('rooms')
# Out:
# 'Коэффициент корреляции цены и'
# 'rooms'
# 0.4763259412934849

# %% [markdown]
# <div style="border:solid purple 2px; padding: 20px"> <b>Выводы 4.4.2:</b>  Коэффициент корреляции ~0.47, зависимость прямая, слабая, при росте количества комнат от 3 снижается.

# %% [markdown]
# #### Зависимость цены от удалённости от центра

# %%
correlation('city_centers_nearest')
# Out:
# 'Коэффициент корреляции цены и'
# 'city_centers_nearest'
# -0.30860548880126615

# %% [markdown]
#  <div style="border:solid purple 2px; padding: 20px"> <b>Выводы 4.4.3:</b>  Коэффициент корреляции -0.3, зависимость обратная, очень слабая, практически ее нет. Число более дорогих квартир возрастает при увеличении расстояния до 5-7 километров от центра, а потом снижается. Заметен всплеск на растоянии 45-55 километров, вероятно отстроен новый жилой комплекс

# %% [markdown]
# #### Зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом.

# %% [markdown]
#   Здесь вычислим среднюю цену по каждой категории этажа, построим столбчатую диаграмму

# %%
floor_category_mean = data.groupby('floor_category')['last_price'].mean()
floor_category_mean.plot(x=floor_category_mean.index, y=floor_category_mean.values, kind='bar', grid=True, figsize=(6,5))
# Out:
# <AxesSubplot:xlabel='floor_category'>

# %% [markdown]
# <div style="border:solid purple 2px; padding: 20px"><b>Выводы 4.4.4:</b>  Очевидно первый этаж наименее популярен среди покупателей, соответственно, и цена у него заметно ниже остальных категорий. Однако, мы не знаем, какую долю выборки занимает коммерческая недвижимость "под магазины/офисы", ее цена гораздо ниже жилой недвижимости. Любителей "пентхаусов" практически столько же, сколько и готовых заплатить за любой другой этаж (не первый и не последний лидер).

# %% [markdown]
# #### Зависимость от даты размещения: дня недели, месяца и года.

# %%
correlation('day_exp')
correlation('month_exp')
correlation('year_exp')
# Out:
# 'Коэффициент корреляции цены и'
# 'day_exp'
# -0.0032972088910040134
# 'Коэффициент корреляции цены и'
# 'month_exp'
# 0.007412421196745882
# 'Коэффициент корреляции цены и'
# 'year_exp'
# -0.05410048950557627

# %%
pivot_table_day_exp = data.pivot_table(index='day_exp', values='last_price', aggfunc=['mean', 'count', 'median'])
pivot_table_day_exp.columns = ['mean', 'count', 'median']
pivot_table_day_exp.plot(y = 'median', grid=True)
pivot_table_day_exp.sort_values('median', ascending = False)
# Out:
#                  mean  count   median
# day_exp
# 1        6.173093e+06   4172  4700000
# 2        6.233887e+06   3963  4700000
# 0        6.258819e+06   3601  4650000
# 3        6.520154e+06   4285  4650000
# 4        6.163823e+06   3990  4562500
# 5        6.133366e+06   1929  4550000
# 6        6.110419e+06   1696  4550000

# %%
pivot_table_month_exp = data.pivot_table(index='month_exp', values='last_price', aggfunc=['mean', 'count', 'median'])
pivot_table_month_exp.columns = ['mean', 'count', 'median']
pivot_table_month_exp.plot(y = 'median', grid=True)
pivot_table_month_exp.sort_values('median', ascending = False)
# Out:
#                    mean  count   median
# month_exp
# 4          6.136158e+06   2370  4800000
# 9          6.383117e+06   1977  4700000
# 11         6.399413e+06   2367  4700000
# 12         6.580995e+06   1639  4700000
# 2          6.265991e+06   2637  4650000
# 3          6.075911e+06   2581  4650000
# 1          6.379913e+06   1496  4600000
# 7          6.322006e+06   1685  4600000
# 8          6.126120e+06   1739  4560000
# 10         5.986730e+06   2119  4550000
# 5          6.325163e+06   1270  4500000
# 6          6.181022e+06   1756  4400000

# %%
pivot_table_year_exp = data.pivot_table(index='year_exp', values='last_price', aggfunc=['mean', 'count', 'median'])
pivot_table_year_exp.columns = ['mean', 'count', 'median']
pivot_table_year_exp.plot(y = 'median', grid=True)
pivot_table_year_exp.sort_values('median', ascending = False)
# Out:
#                   mean  count   median
# year_exp
# 2014      1.208714e+07    137  7700000
# 2015      7.888752e+06   1184  5300500
# 2019      6.549146e+06   2874  5050000
# 2018      5.828624e+06   8499  4550000
# 2016      6.388001e+06   2773  4500000
# 2017      6.200786e+06   8169  4500000

# %% [markdown]
#  <div style="border:solid purple 2px; padding: 20px"> <b>Выводы 4.4.5:</b>  И по ничтожно малым коэффициентам корреляции, и по графикам зависимости нет. Однако, по медианному значению сводной таблицы мы наблюдаем:
#
#  - ко вторнику обычно цена в выкладываемых объявлениях растет, удерживается до среды, и к концу недели только падает. Это можно объяснить общей активностью людей в начале рабочей недели и спадом к выходным
#
#  - сама высокая стоимость недвижимости в апреле (рекордная), в сентябре и устойчивая с ноября по конец года. Самая низкая- в июне (еще бы, сезон отпусков). Сезонный характер рынка недвижимости детектед =)
#
#  - видим, что с 2014 по 2016 год цена уверенно падала, вероятно, это могло быть связано с кризисом начала 2014 года, ростом валюты и обвалом рубля. Устойчивое медианное значение и слабый рост до начала 2018 года также подтверждает эта гипотеза. А в 2018 году ввелись льготные ипотеки под сравнительно небольшие проценты, выросло число новостроек, соответственно, и цена начала подниматься </b>

# %% [markdown]
# <div style="border:solid purple 3px; padding: 20px">  <b>Выводы 4.4:</b>
#
# - Больше всего на стоимость квартиры влияет её площадь(прямопропорцианальная зависимость).
#
# - Среднее влияние оказывает удаленность от центра(обратнопропорцианальная зависимость)
#
# - Количество комнат на стоимость оказывает влияние в отрезке 1-3 комнаты (все, что выше, уже не коррелирует).
#
# - Существует зависимость от категории этажа, цена на первые этажи существенно отличается от остальных (это может быть связано с типом недвижимости - цена на коммерческую недвижимость существенно ниже. В топе не первый и не последний этаж - его цена гораздо выше первого и немного последнего
#
# - На цену влияет активность людей в начале рабочей недели. Отмечен сезонный характер рынка недвижимости. Также глобально на цену влияют финансовые кризисы.

# %% [markdown]
# ### Выберите 10 населённых пунктов с наибольшим числом объявлений.
# Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья.

# %%
local_pivot_table = data.pivot_table(index = 'locality_name', values = 'sq_metr_price', aggfunc=['count', 'mean'])
local_pivot_table.columns = ['count', 'mean']
local_pivot_table = local_pivot_table.sort_values('count', ascending = False).head(10)
local_pivot_table
# Out:
#                    count           mean
# locality_name
# Санкт-Петербург    15711  113543.386544
# поселок Мурино       556   85681.305755
# поселок Шушары       440   78676.904545
# Всеволожск           398   68654.007538
# Пушкин               369  103125.373984
# Колпино              338   75424.150888
# поселок Парголово    327   90175.489297
# Гатчина              307   68745.693811
# деревня Кудрово      299   92473.086957
# Выборг               237   58141.489451

# %%
local_pivot_table[local_pivot_table['mean']==local_pivot_table['mean'].max()]
# Out:
#                  count           mean
# locality_name
# Санкт-Петербург  15711  113543.386544

# %%
local_pivot_table[local_pivot_table['mean']==local_pivot_table['mean'].min()]
# Out:
#                count          mean
# locality_name
# Выборг           237  58141.489451

# %% [markdown]
#  <div style="border:solid purple 2px; padding: 20px"> <b>Выводы 4.5:</b> Таким образом, имеем: самая высокая стоимость жилья из топ10 по количеству объявлений в Санкт-Петербурге (что очевидно), самая низкая в Выборге </div>

# %% [markdown]
# ### Изучите предложения квартир
# для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (locality_name). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется, — это и будет центральная зона.

# %%
spb = data.loc[data['locality_name']=='Санкт-Петербург',['last_price', 'city_centers_nearest']].reset_index(drop=True) 
spb['distance_to_center_km'] = round(spb['city_centers_nearest']/1000).astype(int)
spb.head(10)
# Out:
#    last_price  city_centers_nearest  distance_to_center_km
# 0    13000000               16028.0                     16
# 1     5196000               13933.0                     14
# 2    64900000                6800.0                      7
# 3    10000000                8098.0                      8
# 4     7915000               11634.0                     12
# 5     5400000               15008.0                     15
# 6     5050000               13878.0                     14
# 7     4650000               14259.0                     14
# 8     6700000               10698.0                     11
# 9     4180000               14616.0                     15

# %%
mean_price_km_spb = spb.pivot_table(index='distance_to_center_km', values='last_price', aggfunc='mean')
mean_price_km_spb.head(10)
# Out:
#                          last_price
# distance_to_center_km
# 0                      2.654331e+07
# 1                      1.627076e+07
# 2                      1.504492e+07
# 3                      1.110271e+07
# 4                      1.141150e+07
# 5                      1.279226e+07
# 6                      1.370633e+07
# 7                      1.396663e+07
# 8                      9.248736e+06
# 9                      6.953381e+06

# %%
mean_price_km_spb.plot(kind='bar', grid=True, figsize=(12,5))
# Out:
# <AxesSubplot:xlabel='distance_to_center_km'>

# %%
display(spb.query('city_centers_nearest<1600').sort_values(by='last_price', ascending=False).head(20))
# Out:
#        last_price  city_centers_nearest  distance_to_center_km
# 3731     99000000                1281.0                      1
# 308      95000000                 436.0                      0
# 7523     95000000                1032.0                      1
# 4275     82000000                1280.0                      1
# 5785     80000000                 573.0                      1
# 1337     77000000                1295.0                      1
# 701      75000000                 594.0                      1
# 3998     75000000                 573.0                      1
# 4944     68000000                1253.0                      1
# 9243     65000000                 318.0                      0
# 15203    65000000                1295.0                      1
# 7226     56844500                 318.0                      0
# 5117     50000000                 318.0                      0
# 418      49950000                 945.0                      1
# ...

# %% [markdown]
# <div style="border:solid purple 2px; padding: 20px"> <b>Выводы 4.6:</b> По данным гистограммы можно заключить следующее:
#
# - на расстоянии до 1 (иначе 0 км) км от центра цена пиково* высокая (~ 26,5 млн за квартиру)
#
# - на расстоянии после 1 км. от центра цена резко падает(~ 16,3 млн за квартиру)
#
# - Самым Центром считаем все, что в радиусе до 1 км от центра
#
# - в районе 7-8 км от Самого Центра следует изменение цены (с 14 млн до 9 млн за квартиру) и после начинает плавно снижаться.
#
#     Радиус в 8 км и примем за центральную зону.
#
#     *часть, которая была выше 100 млн, мы обрезали на этапе предобработки (столбец last_price), так же видно, что есть и очень дорогие квартиры
#  </div>

# %% [markdown]
# ### Выделите сегмент квартир в центре.
# Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всей базе?

# %% [markdown]
# #### Выделение сегментов по центру и городу, изучение: площадь, цена, число комнат, высота потолков

# %%
print('Квартиры в центре:')
spb_center = data.query('city_centers_nearest < 8000 and locality_name == "Санкт-Петербург"')
spb_center.head()
# Out:
# Квартиры в центре:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 3              0    64900000       159.0           2015-07-24      3
# 24             8     6500000        97.2           2015-10-31      2
# 35             6    15500000       149.0           2017-06-26      5
# 51             7    45000000       161.0           2017-10-17      3
# 52            20    11795000       136.0           2017-09-22      6
#
#     ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 3              265            14    90.319527      9         False  ...
# 24             265             3    46.500000      1         False  ...
# 35             265             5   104.000000      4         False  ...
# 51             320             8    38.000000      4         False  ...
# 52             300             2    94.000000      2         False  ...
#
#     ponds_around3000  ponds_nearest  days_exposition  sq_metr_price day_exp  \
# ...

# %%
for column in ['total_area', 'last_price', 'rooms', 'ceiling_height']:
    spb_center.plot(y=column, kind='hist', grid=True, figsize=(12,5), bins=75, alpha=0.9, legend=True, label='Центр города - '+column)
    data.plot(y=column, kind='hist', grid=True, figsize=(12,5), bins=75, alpha=0.4, legend=True, label='Общая база - '+column)

# %% [markdown]
# <div style="border:solid purple 2px; padding: 20px"> <b>Выводы 4.7.1:</b>
#
# - В Центре города охотнее покупают квартиры большей площади, нежели по Общей базе
#
# - В Центре цена на квартиры выше, чем в Общей базе (Ваш Кэп)
#
# - В Центре большая доля продаж приходится на 2- и 3-хкомнатные квартиры, тогда как по Общей базе люди приобретают больше  1- и 2-хкомнатные
#
# - В Центре потолки выше - большая доля трехметровых (особенность недвижимости, точнее годов ее постройки), а в Общей базе большая доля потолков высотой 2,5 м. Однако, подавляющее большинство в обоих сегментах соответствует высоте 2,65 м (возможно, тут есть наша вина - медианой-то ее сделали мы, отчего может иметь некоторое искажение данных) </div>

# %% [markdown]
# #### Сравнение Центра города с Общей базой
# Выделяем факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления) и сравниваем Центр города с Общей базой

# %%
def correlation_spb(column):
    plt.show()
    print('Корелляция цены в Центре города и',column , spb_center['last_price'].corr(spb_center[column]))
    spb_center.plot(x=column, y='last_price', kind='scatter', grid=True, figsize=(12,3))
    plt.show()
    print('Корелляция цены по Общей базе и',column , data['last_price'].corr(data[column]))
    data.plot(x=column, y='last_price', kind='scatter', grid=True, figsize=(12,3))

for сol in ['rooms', 'floor', 'city_centers_nearest', 'day_exp', 'month_exp', 'year_exp']:
    correlation_spb(сol)
# Out:
# Корелляция цены в Центре города и rooms 0.4147432091835072
# Корелляция цены по Общей базе и rooms 0.4763259412934849
# Корелляция цены в Центре города и floor 0.13196251029864983
# Корелляция цены по Общей базе и floor 0.03647037320862027
# Корелляция цены в Центре города и city_centers_nearest -0.059695238156326984
# Корелляция цены по Общей базе и city_centers_nearest -0.30860548880126615
# Корелляция цены в Центре города и day_exp 0.019990019794273575
# Корелляция цены по Общей базе и day_exp -0.0032972088910040134
# Корелляция цены в Центре города и month_exp 0.0006776589000430387
# Корелляция цены по Общей базе и month_exp 0.007412421196745882
# Корелляция цены в Центре города и year_exp -0.05469325312644116
# Корелляция цены по Общей базе и year_exp -0.05410048950557627

# %%
floor_category_mean_spb_center = spb_center.groupby('floor_category')['last_price'].mean()
floor_category_mean_data = data.groupby('floor_category')['last_price'].mean()
print('Центр')
plt.show()
floor_category_mean_spb_center.plot(x=floor_category_mean.index, y=floor_category_mean.values, kind='bar', grid=True, figsize=(4,4), alpha=0.5)
plt.show()
print('Общая база')
floor_category_mean_data.plot(x=floor_category_mean.index, y=floor_category_mean.values, kind='bar', grid=True, figsize=(4,4), alpha=0.5)
# Out:
# Центр
# Общая база
# <AxesSubplot:xlabel='floor_category'>

# %% [markdown]
# <div style="border:solid purple 2px; padding: 20px"> <b>Выводы 4.7.2:</b>
#
# - В Центре количество комнат немного слабее влияет на цену
# - В Центре зависимости от удаленности от центра города не (Ваш Кэп-2), в основной массе также отсутствует (есть очень слабая обратная, может свидетельствовать о коттеджных поселках)
# - В сравнении с общим датафреймом здесь подтвердилась моя догадка, которая возникла на этапе зависимости цены от категории этажа. Что в Общей базе, что в Центре стоимость последних этажей заметно выше.Здесь мы брали СРЕДНЕЕ + в любом доме количество квартир на последних этажах кратно меньше количеству квартир типа "другой". Ну и плюс остаются любители "пентхаусов" =)
# - В отношении других параметров зависимость отсутствует

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# <div style="border:solid purple 5px; padding: 20px">
#
# 1. Входными данными для анализа служил датасет из 22 колонок и 23699 строк с информацией по продаже квартир. 7 колонок не пригодились (total_images, open_plan, balcony, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest).
#
# 2. В процессе предобработки было удалено 63 строки, то есть осталось 23636 строк, удалено 0,27% данных - вполне хорошо.
#   - при обработке пропущенных значений использованы прямые и взаимосвязанные замены медианами,
#   - обнаружены и исправлены ошибочно введенные значения,
#   - столбцы приводились к типам int64 и datetime64,
#   - обрезаны выдающиеся значения,
#   - удалены дубликаты,
#   - произведена замена пропусков средними значениями,
#   - записан **датафрейм *unfilled_data*** в п. 2.1.17 со строками, в которых имеются пропуски в расстояниях (столбцы airports_nearest, parks_nearest, ponds_nearest и cityCenters_nearest(!)) **Баг-репорт**
#   - четыре столбца с расстоянием и один с количеством дней объявления были заполнены согласно алгоритму соответствия "расстояние/населенный пункт"
#
# 3. На этапе расчетов было добавлено 7 столбцов, в которых подсчитаны дополнительные параметры:
#   - цена квадратного метра
#   - день недели, месяц и год публикации объявления
#   - этаж квартиры; варианты — первый, последний, другой
#   - соотношение жилой и общей площади
#   - соотношение площади кухни к общей.
#
# 4. Проведен анализ и сделаны выводы по заданым вопросам:
#     - 1- и 2-хкомнатные квартиры с площадями от 31 до 46 м2 являются наиболее популярными на рынке жилья
#     - затем квартиры с общей площадью до 76 м2 (скорее всего двух-или трехкомнатные)
#     - популярность квартир с большими площадями прямо убывает, что логично
#     - микро-квартиры до 26-30 м2 замыкают наш рейтинг
#
#     - квартиры стоимостью от 3,9 млн до 4,4 млн самые распространенные
#     - квартиры в общей массе стоимостью от 1,8-1,9 млн и до 7,2 млн являются наиболее востребованными на рынке жилья
#     - для диапазона от 7,2 млн: чем выше стоимость и больше площадь жилья пропорционально ниже интерес
#     - для диапазона до 2 млн: чем выше стоимость и больше площадь жилья пропорционально выше интерес
#     - однокомнатные являются наиболее популярными на рынке жилья (более 8000 предложений), чуть менее популярны двухкомнатные
#     - больше всего квартир с высотой потолка от 240 до 280 см, на них приходится ~ 19500 предложений, затем квартиры с высотой 280-360 см (~3000)
#     - при изучении времени продажи квартиры диаграмма размаха (от минимального значения до ~ 500 дней) выявила, что необоснованно быстрых продаж у нас нет, а необоснованно долгие - от 500 дней и выше. Можно считать нормальным продажу квартиры до ~ 1.2 года. *ОДНАКО* при укрупнении диаграммы обнаружились резко выбивающиеся значения. Проверив их .value_counts(), убедились, что имеем аномальные значения - 45, 60, 7, 30, 90 (и подозрительно ровные). Яндекс.Справка подсказала, что эти сроки - границы того, что объявление утрачивает актуальность и снимается за ненадобностью автоматически. Не трогая основного датасета, сохранили эти значения в **датафреймы *anomalous_data_45, anomalous_data_60, anomalous_data_7, anomalous_data_30, anomalous_data_90***  как **баг-репорт (п. 4.3)** Проблема в днях снятия может крыться в разных ошибках - к примеру, объявление могло быть помечено не на продажу, а на аренду - его срок снятия зависит от вида объекта и длительности аренды (здесь либо 7, либо 30 дней). Коллегам надо проверить. Как и ожидалось, в очищенных данных и данных с аномалиями нормальные значения сместились на 2 месяца вперед.
#
#     - Больше всего на стоимость квартиры влияет её площадь (прямопропорцианальная зависимость).
#     - Среднее влияние оказывает удаленность от центра (обратнопропорцианальная зависимость)
#     - Количество комнат на стоимость оказывает влияние в отрезке 1-3 комнаты (все, что выше, уже не коррелирует).
#     - Существует зависимость от категории этажа, цена на первые этажи существенно отличается от остальных (это может быть связано с типом недвижимости - цена на коммерческую недвижимость существенно ниже. В топе не первый и не последний этаж - его цена гораздо выше первого и немного последнего
#     - На цену влияет активность людей в начале рабочей недели. Отмечен сезонный характер рынка недвижимости. Также глобально на цену влияют финансовые кризисы.
#
#     - Подавляющее большинство квартир продается в Питере - 15712, а цена около 113500р/кв.м. Помимо Питера в Топ10 входят: поселок Мурино, поселок Шушары, Всеволожск, Пушкин, Колпино, поселок Парголово, Гатчина, деревня Кудрово, Выборг с ценами 58000 - 85500р/кв.м
#
#     - На расстоянии до 1 (иначе 0 км) км от центра цена пиково* высокая (~ 26,5 млн за квартиру), на расстоянии после 1 км. от центра цена резко падает(~ 16,3 млн за квартиру). Самым Центром считаем все, что в радиусе до 1 км от центра. В районе 7-8 км от Самого Центра следует изменение цены (с 14 млн до 9 млн за квартиру) и после начинает плавно снижаться.
#     - Радиус в 8 км и принят за центральную зону.
#
#     - В Центре охотнее покупают квартиры большей площади, нежели по Общей базе; цена на квартиры выше, чем в Общей базе; большая доля продаж приходится на 2- и 3-хкомнатные квартиры, тогда как по Общей базе люди приобретают больше 1- и 2-хкомнатные; потолки выше - большая доля трехметровых (особенность недвижимости, точнее годов ее постройки), а в Городе большая доля потолков высотой 2,5 м. Однако, подавляющее большинство в обоих сегментах соответствует высоте 2,65 м
#     - В Центре количество комнат немного слабее влияет на цену
#     - В Центре зависимости от удаленности от центра города нет, в Общей базе прослеживается слабая обратная зависимость
#     - В сравнении с общим датафреймом здесь подтвердилась моя догадка, которая возникла на этапе зависимости цены от категории этажа. Что в Общей базе, что в Центре стоимость последних этажей заметно выше.Здесь мы брали СРЕДНЕЕ + в любом доме количество квартир на последних этажах кратно меньше количеству квартир типа "другой". Ну и плюс остаются любители "пентхаусов" =)
#     - В отношении других параметров зависимость отсутствует
